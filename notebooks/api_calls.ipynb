# %% [markdown]
# ## Using this notebook to test the api_calls functions and creating csv dumps to use for analysis in another notebook

# %% [markdown]
# ### Packages we use

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
from crossfitgames.api.api_calls import *
import time

# %% [markdown]
# ### Calling the api to show what the returned data looks like

# %%
games_json_dump(2007,1)
# Out:
# 2025-01-01 13:52:54,320 - INFO - Starting API call for year 2007, division 1 and page 1
# 2025-01-01 13:52:54,677 - INFO - Successfully fetched data for year 2007, division 1 and page 1
# {'version': 3,
#  'dataType': 'LEADERBOARD',
#  'query': 'query-string',
#  'sort': 0,
#  'pagination': {'totalPages': 1, 'totalCompetitors': 44, 'currentPage': 1},
#  'competition': {'year': 2007,
#   'competitionType': 'games',
#   'competitionId': 59,
#   'division': '1',
#   'scaled': '0',
#   'countryId': '',
#   'countryName': '',
#   'fittestIn': '',
#   'inSubCat': ''},
#  'ordinals': [{'ordinal': '1', 'columnName': '1'},
#   {'ordinal': '2', 'columnName': '2'},
#   {'ordinal': '3', 'columnName': '3'}],
#  'leaderboardRows': [{'overallRank': '1',
#    'overallScore': '272',
#    'nextStage': '',
#    'ui': {'highlight': False, 'countryChampion': False},
#    'entrant': {'competitorId': '164070',
#     'competitorName': 'James Fitzgerald',
#     'firstName': 'James',
#     'lastName': 'Fitzgerald',
#     'status': 'ACT',
#     'postCompStatus': '',
#     'gender': 'M',
#     'profilePicS3key': '0a1aa-P164070_2-184.jpg',
#     'countryOfOriginCode': '',
#     'countryOfOriginName': '',
#     'countryShortCode': '',
#     'regionId': 'None',
#     'regionName': '',
#     'divisionId': '1',
#     'affiliateId': 'None',
#     'affiliateName': '',
#     'age': '33',
#     'height': '69 in',
#     'weight': '176 lb',
#     'teamCaptain': '0'},
#    'scores': [{'ordinal': 1,
#      'rank': '2',
#      'score': '95',
#      'valid': '1',
#      'scoreDisplay': '13:39',
#      'scoreIdentifier': '75881c2cd249b98185a8',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '95 pts'},
#     {'ordinal': 2,
#      'rank': '2',
#      'score': '95',
#      'valid': '1',
#      'scoreDisplay': '20:45',
#      'scoreIdentifier': 'bf9d6716056044146079',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '95 pts'},
#     {'ordinal': 3,
#      'rank': '11',
#      'score': '82',
#      'valid': '1',
#      'scoreDisplay': '906.4 lb',
#      'scoreIdentifier': 'a355dcd3303b9b861ba0',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '82 pts'}]},
#   {'overallRank': '2',
#    'overallScore': '270',
#    'nextStage': '',
#    'ui': {'highlight': False, 'countryChampion': False},
#    'entrant': {'competitorId': '57785',
#     'competitorName': 'Brett Marshall',
#     'firstName': 'Brett',
#     'lastName': 'Marshall',
#     'status': 'ACT',
#     'postCompStatus': '',
#     'gender': 'M',
#     'profilePicS3key': 'e11d1-P57785_2-184.jpg',
#     'countryOfOriginCode': '',
#     'countryOfOriginName': '',
#     'countryShortCode': '',
#     'regionId': 'None',
#     'regionName': '',
#     'divisionId': '1',
#     'affiliateId': 'None',
#     'affiliateName': '',
#     'age': '33',
#     'height': '168 cm',
#     'weight': '155 lb',
#     'teamCaptain': '0'},
#    'scores': [{'ordinal': 1,
#      'rank': '1',
#      'score': '100',
#      'valid': '1',
#      'scoreDisplay': '13:07',
#      'scoreIdentifier': 'ed155ea36b3781f16914',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '100 pts'},
#     {'ordinal': 2,
#      'rank': '3',
#      'score': '90',
#      'valid': '1',
#      'scoreDisplay': '22:00',
#      'scoreIdentifier': 'b25717e51efa6f0d783d',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '90 pts'},
#     {'ordinal': 3,
#      'rank': '13',
#      'score': '80',
#      'valid': '1',
#      'scoreDisplay': '891 lb',
#      'scoreIdentifier': 'fe065c6227ca2e5e3c92',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '80 pts'}]},
#   {'overallRank': '3',
#    'overallScore': '267',
#    'nextStage': '',
#    'ui': {'highlight': False, 'countryChampion': False},
#    'entrant': {'competitorId': '10091',
#     'competitorName': 'Josh Everett',
#     'firstName': 'Josh',
#     'lastName': 'Everett',
#     'status': 'ACT',
#     'postCompStatus': '',
#     'gender': 'M',
#     'profilePicS3key': '98160-P10091_2-184.jpg',
#     'countryOfOriginCode': '',
#     'countryOfOriginName': '',
#     'countryShortCode': '',
#     'regionId': 'None',
#     'regionName': '',
#     'divisionId': '1',
#     'affiliateId': 'None',
#     'affiliateName': '',
#     'age': '32',
#     'height': '69 in',
#     'weight': '185 lb',
#     'teamCaptain': '0'},
#    'scores': [{'ordinal': 1,
#      'rank': '4',
#      'score': '89',
#      'valid': '1',
#      'scoreDisplay': '14:13',
#      'scoreIdentifier': 'ff0057b37547b194805c',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '89 pts'},
#     {'ordinal': 2,
#      'rank': '10',
#      'score': '83',
#      'valid': '1',
#      'scoreDisplay': '24:28',
#      'scoreIdentifier': '651667a1275e5f027d17',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '83 pts'},
#     {'ordinal': 3,
#      'rank': '2',
#      'score': '95',
#      'valid': '1',
#      'scoreDisplay': '1133 lb',
#      'scoreIdentifier': '3c141f963fba08ac39db',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '95 pts'}]},
#   {'overallRank': '4',
#    'overallScore': '261',
#    'nextStage': '',
#    'ui': {'highlight': False, 'countryChampion': False},
#    'entrant': {'competitorId': '27065',
#     'competitorName': 'Chris Spealler',
#     'firstName': 'Chris',
#     'lastName': 'Spealler',
#     'status': 'ACT',
#     'postCompStatus': '',
#     'gender': 'M',
#     'profilePicS3key': '28faf-P27065_3-184.jpg',
#     'countryOfOriginCode': '',
#     'countryOfOriginName': '',
#     'countryShortCode': '',
#     'regionId': 'None',
#     'regionName': '',
#     'divisionId': '1',
#     'affiliateId': 'None',
#     'affiliateName': '',
#     'age': '28',
#     'height': '65 in',
#     'weight': '143 lb',
#     'teamCaptain': '0'},
#    'scores': [{'ordinal': 1,
#      'rank': '3',
#      'score': '90',
#      'valid': '1',
#      'scoreDisplay': '13:52',
#      'scoreIdentifier': '41dbb5bf3963361e88db',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '90 pts'},
#     {'ordinal': 2,
#      'rank': '1',
#      'score': '100',
#      'valid': '1',
#      'scoreDisplay': '20:43',
#      'scoreIdentifier': '2610ac7ff1ffbaf6d88f',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '100 pts'},
#     {'ordinal': 3,
#      'rank': '22',
#      'score': '71',
#      'valid': '1',
#      'scoreDisplay': '756.8 lb',
#      'scoreIdentifier': '5f7c04c3483f5ca0c90b',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '71 pts'}]},
#   {'overallRank': '5',
#    'overallScore': '252',
#    'nextStage': '',
#    'ui': {'highlight': False, 'countryChampion': False},
#    'entrant': {'competitorId': '7173',
#     'competitorName': 'Breck Berry',
#     'firstName': 'Breck',
#     'lastName': 'Berry',
#     'status': 'ACT',
#     'postCompStatus': '',
#     'gender': 'M',
#     'profilePicS3key': 'f142a-P7173_6-184.jpg',
#     'countryOfOriginCode': '',
#     'countryOfOriginName': '',
#     'countryShortCode': '',
#     'regionId': 'None',
#     'regionName': '',
#     'divisionId': '1',
#     'affiliateId': 'None',
#     'affiliateName': '',
#     'age': '31',
#     'height': '67 in',
#     'weight': '170 lb',
#     'teamCaptain': '0'},
#    'scores': [{'ordinal': 1,
#      'rank': '13',
#      'score': '80',
#      'valid': '1',
#      'scoreDisplay': '18:21',
#      'scoreIdentifier': 'ee1958aeb423fcc37d8c',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '80 pts'},
#     {'ordinal': 2,
#      'rank': '4',
#      'score': '89',
#      'valid': '1',
#      'scoreDisplay': '22:04',
#      'scoreIdentifier': '0968e9f284579894a1e7',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '89 pts'},
#     {'ordinal': 3,
#      'rank': '10',
#      'score': '83',
#      'valid': '1',
#      'scoreDisplay': '906.4 lb',
#      'scoreIdentifier': '1f5a796526106eaf4b1b',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '83 pts'}]},
#   {'overallRank': '6',
#    'overallScore': '248',
#    'nextStage': '',
#    'ui': {'highlight': False, 'countryChampion': False},
#    'entrant': {'competitorId': '642463',
#     'competitorName': 'Jeremy Thiel',
#     'firstName': 'Jeremy',
#     'lastName': 'Thiel',
#     'status': 'ACT',
#     'postCompStatus': '',
#     'gender': 'M',
#     'profilePicS3key': 'a69c0-P642463_1-184.jpg',
#     'countryOfOriginCode': '',
#     'countryOfOriginName': '',
#     'countryShortCode': '',
#     'regionId': 'None',
#     'regionName': '',
#     'divisionId': '1',
#     'affiliateId': 'None',
#     'affiliateName': '',
#     'age': '25',
#     'height': '',
#     'weight': '205 lb',
#     'teamCaptain': '0'},
#    'scores': [{'ordinal': 1,
#      'rank': '19',
#      'score': '74',
#      'valid': '1',
#      'scoreDisplay': 'Rnd 5 13 Pullups',
#      'scoreIdentifier': 'cc384bf0458a7ad6e149',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '74 pts'},
#     {'ordinal': 2,
#      'rank': '7',
#      'score': '86',
#      'valid': '1',
#      'scoreDisplay': '23:56',
#      'scoreIdentifier': 'c0dff334d8dd99aa8018',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '86 pts'},
#     {'ordinal': 3,
#      'rank': '5',
#      'score': '88',
#      'valid': '1',
#      'scoreDisplay': '974.8 lb',
#      'scoreIdentifier': '2c6d561fedfebac1bfd1',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '88 pts'}]},
#   {'overallRank': '7',
#    'overallScore': '243',
#    'nextStage': '',
#    'ui': {'highlight': False, 'countryChampion': False},
#    'entrant': {'competitorId': '1673635',
#     'competitorName': 'Brendan Gilliam',
#     'firstName': 'Brendan',
#     'lastName': 'Gilliam',
#     'status': 'ACT',
#     'postCompStatus': '',
#     'gender': 'M',
#     'profilePicS3key': 'men-square.jpg',
#     'countryOfOriginCode': '',
#     'countryOfOriginName': '',
#     'countryShortCode': '',
#     'regionId': 'None',
#     'regionName': '',
#     'divisionId': '1',
#     'affiliateId': 'None',
#     'affiliateName': '',
#     'age': '30',
#     'height': '72 in',
#     'weight': '185 lb',
#     'teamCaptain': '0'},
#    'scores': [{'ordinal': 1,
#      'rank': '5',
#      'score': '88',
#      'valid': '1',
#      'scoreDisplay': '15:35',
#      'scoreIdentifier': '706897f8758ac09a1b68',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '88 pts'},
#     {'ordinal': 2,
#      'rank': '16',
#      'score': '77',
#      'valid': '1',
#      'scoreDisplay': '25:39',
#      'scoreIdentifier': '8efdb536ceab395b362b',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '77 pts'},
#     {'ordinal': 3,
#      'rank': '15',
#      'score': '78',
#      'valid': '1',
#      'scoreDisplay': '866.8 lb',
#      'scoreIdentifier': '6b5aa37ec66ef9ee6b6a',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '78 pts'}]},
#   {'overallRank': '8',
#    'overallScore': '239',
#    'nextStage': '',
#    'ui': {'highlight': False, 'countryChampion': False},
#    'entrant': {'competitorId': '2377125',
#     'competitorName': 'Evan Von',
#     'firstName': 'Evan',
#     'lastName': 'Von',
#     'status': 'ACT',
#     'postCompStatus': '',
#     'gender': 'M',
#     'profilePicS3key': 'men-square.jpg',
#     'countryOfOriginCode': '',
#     'countryOfOriginName': '',
#     'countryShortCode': '',
#     'regionId': 'None',
#     'regionName': '',
#     'divisionId': '1',
#     'affiliateId': 'None',
#     'affiliateName': '',
#     'age': '0',
#     'height': '',
#     'weight': '',
#     'teamCaptain': '0'},
#    'scores': [{'ordinal': 1,
#      'rank': '9',
#      'score': '84',
#      'valid': '1',
#      'scoreDisplay': '17:25',
#      'scoreIdentifier': 'e58e6458ba2cddc845ec',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '84 pts'},
#     {'ordinal': 2,
#      'rank': '28',
#      'score': '65',
#      'valid': '1',
#      'scoreDisplay': '27:25',
#      'scoreIdentifier': 'bbd639731e22b1ad74db',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '65 pts'},
#     {'ordinal': 3,
#      'rank': '3',
#      'score': '90',
#      'valid': '1',
#      'scoreDisplay': '1025 lb',
#      'scoreIdentifier': 'bbd8ca97362819e43278',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '90 pts'}]},
#   {'overallRank': '9',
#    'overallScore': '235',
#    'nextStage': '',
#    'ui': {'highlight': False, 'countryChampion': False},
#    'entrant': {'competitorId': '2377126',
#     'competitorName': 'Brent Oakson',
#     'firstName': 'Brent',
#     'lastName': 'Oakson',
#     'status': 'ACT',
#     'postCompStatus': '',
#     'gender': 'M',
#     'profilePicS3key': 'men-square.jpg',
#     'countryOfOriginCode': '',
#     'countryOfOriginName': '',
#     'countryShortCode': '',
#     'regionId': 'None',
#     'regionName': '',
#     'divisionId': '1',
#     'affiliateId': 'None',
#     'affiliateName': '',
#     'age': '0',
#     'height': '',
#     'weight': '',
#     'teamCaptain': '0'},
#    'scores': [{'ordinal': 1,
#      'rank': '7',
#      'score': '86',
#      'valid': '1',
#      'scoreDisplay': '16:53',
#      'scoreIdentifier': '961816de677708818a4f',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '86 pts'},
#     {'ordinal': 2,
#      'rank': '17',
#      'score': '76',
#      'valid': '1',
#      'scoreDisplay': '25:44',
#      'scoreIdentifier': 'cdfe976e6dc1a8f6a958',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '76 pts'},
#     {'ordinal': 3,
#      'rank': '20',
#      'score': '73',
#      'valid': '1',
#      'scoreDisplay': '781 lb',
#      'scoreIdentifier': '2fc7bba053c009d7fc86',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '73 pts'}]},
#   {'overallRank': '10',
#    'overallScore': '232',
#    'nextStage': '',
#    'ui': {'highlight': False, 'countryChampion': False},
#    'entrant': {'competitorId': '32710',
#     'competitorName': 'Peter Egyed',
#     'firstName': 'Peter',
#     'lastName': 'Egyed',
#     'status': 'ACT',
#     'postCompStatus': '',
#     'gender': 'M',
#     'profilePicS3key': '2f591-P32710_2-184.jpg',
#     'countryOfOriginCode': '',
#     'countryOfOriginName': '',
#     'countryShortCode': '',
#     'regionId': 'None',
#     'regionName': '',
#     'divisionId': '1',
#     'affiliateId': 'None',
#     'affiliateName': '',
#     'age': '21',
#     'height': '71 in',
#     'weight': '193 lb',
#     'teamCaptain': '0'},
#    'scores': [{'ordinal': 1,
#      'rank': '23',
#      'score': '70',
#      'valid': '1',
#      'scoreDisplay': 'Rnd 5 3 Pullups',
#      'scoreIdentifier': '5fa18b38a5334bcee84f',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '70 pts'},
#     {'ordinal': 2,
#      'rank': '15',
#      'score': '78',
#      'valid': '1',
#      'scoreDisplay': '25:21',
#      'scoreIdentifier': 'dc9abad85916432e84f2',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '78 pts'},
#     {'ordinal': 3,
#      'rank': '9',
#      'score': '84',
#      'valid': '1',
#      'scoreDisplay': '913 lb',
#      'scoreIdentifier': '91a7f7b27efedb7f75cf',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '84 pts'}]},
#   {'overallRank': '11',
#    'overallScore': '232',
#    'nextStage': '',
#    'ui': {'highlight': False, 'countryChampion': False},
#    'entrant': {'competitorId': '1616',
#     'competitorName': 'Russ Greene',
#     'firstName': 'Russ',
#     'lastName': 'Greene',
#     'status': 'ACT',
#     'postCompStatus': '',
#     'gender': 'M',
#     'profilePicS3key': 'men-square.jpg',
#     'countryOfOriginCode': '',
#     'countryOfOriginName': '',
#     'countryShortCode': '',
#     'regionId': 'None',
#     'regionName': '',
#     'divisionId': '1',
#     'affiliateId': 'None',
#     'affiliateName': '',
#     'age': '20',
#     'height': '70 in',
#     'weight': '183 lb',
#     'teamCaptain': '0'},
#    'scores': [{'ordinal': 1,
#      'rank': '16',
#      'score': '77',
#      'valid': '1',
#      'scoreDisplay': '19:24',
#      'scoreIdentifier': '66aef14b004f9d7c49bf',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '77 pts'},
#     {'ordinal': 2,
#      'rank': '12',
#      'score': '81',
#      'valid': '1',
#      'scoreDisplay': '24:33',
#      'scoreIdentifier': '0c969ced0f4739a2c5c4',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '81 pts'},
#     {'ordinal': 3,
#      'rank': '19',
#      'score': '74',
#      'valid': '1',
#      'scoreDisplay': '798.6 lb',
#      'scoreIdentifier': 'f2d611a14ebddfde5178',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '74 pts'}]},
#   {'overallRank': '12',
#    'overallScore': '226',
#    'nextStage': '',
#    'ui': {'highlight': False, 'countryChampion': False},
#    'entrant': {'competitorId': '15607',
#     'competitorName': 'Dale Saran',
#     'firstName': 'Dale',
#     'lastName': 'Saran',
#     'status': 'ACT',
#     'postCompStatus': '',
#     'gender': 'M',
#     'profilePicS3key': '5b32c-P15607_5-184.jpg',
#     'countryOfOriginCode': '',
#     'countryOfOriginName': '',
#     'countryShortCode': '',
#     'regionId': 'None',
#     'regionName': '',
#     'divisionId': '1',
#     'affiliateId': 'None',
#     'affiliateName': '',
#     'age': '37',
#     'height': '66 in',
#     'weight': '190 lb',
#     'teamCaptain': '0'},
#    'scores': [{'ordinal': 1,
#      'rank': '17',
#      'score': '76',
#      'valid': '1',
#      'scoreDisplay': 'Rnd 5 4 jerks',
#      'scoreIdentifier': '6f003973ac13a993baec',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '76 pts'},
#     {'ordinal': 2,
#      'rank': '32',
#      'score': '61',
#      'valid': '1',
#      'scoreDisplay': '28:35',
#      'scoreIdentifier': '97a1d4001a7413353280',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '61 pts'},
#     {'ordinal': 3,
#      'rank': '4',
#      'score': '89',
#      'valid': '1',
#      'scoreDisplay': '1005 lb',
#      'scoreIdentifier': 'bcf1c70ed8e353939d4d',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '89 pts'}]},
#   {'overallRank': '13',
#    'overallScore': '226',
#    'nextStage': '',
#    'ui': {'highlight': False, 'countryChampion': False},
#    'entrant': {'competitorId': '13082',
#     'competitorName': 'Freddy Camacho',
#     'firstName': 'Freddy',
#     'lastName': 'Camacho',
#     'status': 'ACT',
#     'postCompStatus': '',
#     'gender': 'M',
#     'profilePicS3key': 'f08be-P13082_9-184.jpg',
#     'countryOfOriginCode': '',
#     'countryOfOriginName': '',
#     'countryShortCode': '',
#     'regionId': 'None',
#     'regionName': '',
#     'divisionId': '1',
#     'affiliateId': 'None',
#     'affiliateName': '',
#     'age': '42',
#     'height': '68 in',
#     'weight': '190 lb',
#     'teamCaptain': '0'},
#    'scores': [{'ordinal': 1,
#      'rank': '14',
#      'score': '79',
#      'valid': '1',
#      'scoreDisplay': '18:30',
#      'scoreIdentifier': 'ad0614b0ef6b17e435d1',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '79 pts'},
#     {'ordinal': 2,
#      'rank': '25',
#      'score': '68',
#      'valid': '1',
#      'scoreDisplay': '27:01',
#      'scoreIdentifier': '2012a6353f8bbeaada70',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '68 pts'},
#     {'ordinal': 3,
#      'rank': '14',
#      'score': '79',
#      'valid': '1',
#      'scoreDisplay': '870 lb',
#      'scoreIdentifier': 'e12e3e4e554263524b7d',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '79 pts'}]},
#   {'overallRank': '14',
#    'overallScore': '224',
#    'nextStage': '',
#    'ui': {'highlight': False, 'countryChampion': False},
#    'entrant': {'competitorId': '441600',
#     'competitorName': 'Connor Banks',
#     'firstName': 'Connor',
#     'lastName': 'Banks',
#     'status': 'ACT',
#     'postCompStatus': '',
#     'gender': 'M',
#     'profilePicS3key': '189da-P441600_3-184.jpg',
#     'countryOfOriginCode': '',
#     'countryOfOriginName': '',
#     'countryShortCode': '',
#     'regionId': 'None',
#     'regionName': '',
#     'divisionId': '1',
#     'affiliateId': 'None',
#     'affiliateName': '',
#     'age': '24',
#     'height': '75 in',
#     'weight': '265 lb',
#     'teamCaptain': '0'},
#    'scores': [{'ordinal': 1,
#      'rank': '31',
#      'score': '62',
#      'valid': '1',
#      'scoreDisplay': 'Rnd 3 21 Pullups',
#      'scoreIdentifier': 'c8feb77666c579f87676',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '62 pts'},
#     {'ordinal': 2,
#      'rank': '31',
#      'score': '62',
#      'valid': '1',
#      'scoreDisplay': '28:07',
#      'scoreIdentifier': 'c7cfa0c29d64e446e3a2',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '62 pts'},
#     {'ordinal': 3,
#      'rank': '1',
#      'score': '100',
#      'valid': '1',
#      'scoreDisplay': '1225 lb',
#      'scoreIdentifier': 'f3a8af0beebd490f693d',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '100 pts'}]},
#   {'overallRank': '15',
#    'overallScore': '223',
#    'nextStage': '',
#    'ui': {'highlight': False, 'countryChampion': False},
#    'entrant': {'competitorId': '21298',
#     'competitorName': 'Mike Hom',
#     'firstName': 'Mike',
#     'lastName': 'Hom',
#     'status': 'ACT',
#     'postCompStatus': '',
#     'gender': 'M',
#     'profilePicS3key': 'men-square.jpg',
#     'countryOfOriginCode': '',
#     'countryOfOriginName': '',
#     'countryShortCode': '',
#     'regionId': 'None',
#     'regionName': '',
#     'divisionId': '1',
#     'affiliateId': 'None',
#     'affiliateName': '',
#     'age': '24',
#     'height': '',
#     'weight': '',
#     'teamCaptain': '0'},
#    'scores': [{'ordinal': 1,
#      'rank': '12',
#      'score': '81',
#      'valid': '1',
#      'scoreDisplay': '18:08',
#      'scoreIdentifier': '7202a95a6371528f6307',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '81 pts'},
#     {'ordinal': 2,
#      'rank': '38',
#      'score': '55',
#      'valid': '1',
#      'scoreDisplay': '31:25',
#      'scoreIdentifier': '4906248cbe6b82086175',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '55 pts'},
#     {'ordinal': 3,
#      'rank': '6',
#      'score': '87',
#      'valid': '1',
#      'scoreDisplay': '945 lb',
#      'scoreIdentifier': 'b50ea1ba9a8c16eb22cc',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '87 pts'}]},
#   {'overallRank': '16',
#    'overallScore': '222',
#    'nextStage': '',
#    'ui': {'highlight': False, 'countryChampion': False},
#    'entrant': {'competitorId': '2377127',
#     'competitorName': 'John Murphy',
#     'firstName': 'John',
#     'lastName': 'Murphy',
#     'status': 'ACT',
#     'postCompStatus': '',
#     'gender': 'M',
#     'profilePicS3key': 'men-square.jpg',
#     'countryOfOriginCode': '',
#     'countryOfOriginName': '',
#     'countryShortCode': '',
#     'regionId': 'None',
#     'regionName': '',
#     'divisionId': '1',
#     'affiliateId': 'None',
#     'affiliateName': '',
#     'age': '0',
#     'height': '',
#     'weight': '',
#     'teamCaptain': '0'},
#    'scores': [{'ordinal': 1,
#      'rank': '11',
#      'score': '82',
#      'valid': '1',
#      'scoreDisplay': '17:27',
#      'scoreIdentifier': 'b48ad81ba5cf1a788b0e',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '82 pts'},
#     {'ordinal': 2,
#      'rank': '30',
#      'score': '63',
#      'valid': '1',
#      'scoreDisplay': '27:51',
#      'scoreIdentifier': '97f93100ba8da4824214',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '63 pts'},
#     {'ordinal': 3,
#      'rank': '16',
#      'score': '77',
#      'valid': '1',
#      'scoreDisplay': '855 lb',
#      'scoreIdentifier': '7a6cc801c6dfeecb61c0',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '77 pts'}]},
#   {'overallRank': '17',
#    'overallScore': '222',
#    'nextStage': '',
#    'ui': {'highlight': False, 'countryChampion': False},
#    'entrant': {'competitorId': '2377128',
#     'competitorName': 'Ryan Wolley',
#     'firstName': 'Ryan',
#     'lastName': 'Wolley',
#     'status': 'ACT',
#     'postCompStatus': '',
#     'gender': 'M',
#     'profilePicS3key': 'men-square.jpg',
#     'countryOfOriginCode': '',
#     'countryOfOriginName': '',
#     'countryShortCode': '',
#     'regionId': 'None',
#     'regionName': '',
#     'divisionId': '1',
#     'affiliateId': 'None',
#     'affiliateName': '',
#     'age': '0',
#     'height': '',
#     'weight': '',
#     'teamCaptain': '0'},
#    'scores': [{'ordinal': 1,
#      'rank': '21',
#      'score': '72',
#      'valid': '1',
#      'scoreDisplay': 'Rnd 5 22 Pullups',
#      'scoreIdentifier': '32e9a7a7a20f2ba5d5ef',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '72 pts'},
#     {'ordinal': 2,
#      'rank': '11',
#      'score': '82',
#      'valid': '1',
#      'scoreDisplay': '24:30',
#      'scoreIdentifier': '659b4959afd50ee51aba',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '82 pts'},
#     {'ordinal': 3,
#      'rank': '25',
#      'score': '68',
#      'valid': '1',
#      'scoreDisplay': '720 lb',
#      'scoreIdentifier': 'ef1e7ab79772744efe5b',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '68 pts'}]},
#   {'overallRank': '18',
#    'overallScore': '221',
#    'nextStage': '',
#    'ui': {'highlight': False, 'countryChampion': False},
#    'entrant': {'competitorId': '1818745',
#     'competitorName': 'Brian Vandewettering',
#     'firstName': 'Brian',
#     'lastName': 'Vandewettering',
#     'status': 'ACT',
#     'postCompStatus': '',
#     'gender': 'M',
#     'profilePicS3key': 'men-square.jpg',
#     'countryOfOriginCode': '',
#     'countryOfOriginName': '',
#     'countryShortCode': '',
#     'regionId': 'None',
#     'regionName': '',
#     'divisionId': '1',
#     'affiliateId': 'None',
#     'affiliateName': '',
#     'age': '44',
#     'height': '',
#     'weight': '',
#     'teamCaptain': '0'},
#    'scores': [{'ordinal': 1,
#      'rank': '25',
#      'score': '68',
#      'valid': '1',
#      'scoreDisplay': 'Rnd 4 24 Pullups',
#      'scoreIdentifier': '199996dbe2c0b9f2f06b',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '68 pts'},
#     {'ordinal': 2,
#      'rank': '26',
#      'score': '67',
#      'valid': '1',
#      'scoreDisplay': '27:09',
#      'scoreIdentifier': 'a28e523553b39ffa7157',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '67 pts'},
#     {'ordinal': 3,
#      'rank': '7',
#      'score': '86',
#      'valid': '1',
#      'scoreDisplay': '915 lb',
#      'scoreIdentifier': '798deb1e12a9b2ca909b',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '86 pts'}]},
#   {'overallRank': '19',
#    'overallScore': '220',
#    'nextStage': '',
#    'ui': {'highlight': False, 'countryChampion': False},
#    'entrant': {'competitorId': '30675',
#     'competitorName': 'Marcus Neal',
#     'firstName': 'Marcus',
#     'lastName': 'Neal',
#     'status': 'ACT',
#     'postCompStatus': '',
#     'gender': 'M',
#     'profilePicS3key': '765c0-P30675_2-184.jpg',
#     'countryOfOriginCode': '',
#     'countryOfOriginName': '',
#     'countryShortCode': '',
#     'regionId': 'None',
#     'regionName': '',
#     'divisionId': '1',
#     'affiliateId': 'None',
#     'affiliateName': '',
#     'age': '27',
#     'height': '72 in',
#     'weight': '210 lb',
#     'teamCaptain': '0'},
#    'scores': [{'ordinal': 1,
#      'rank': '24',
#      'score': '69',
#      'valid': '1',
#      'scoreDisplay': 'Rnd 4 25 Pullups',
#      'scoreIdentifier': 'c0181ac06e449d557dc8',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '69 pts'},
#     {'ordinal': 2,
#      'rank': '23',
#      'score': '70',
#      'valid': '1',
#      'scoreDisplay': '26:37',
#      'scoreIdentifier': '76b00cffe95f53a57a6d',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '70 pts'},
#     {'ordinal': 3,
#      'rank': '12',
#      'score': '81',
#      'valid': '1',
#      'scoreDisplay': '906.4 lb',
#      'scoreIdentifier': 'fd64e80d40c3a5c0adf0',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '81 pts'}]},
#   {'overallRank': '20',
#    'overallScore': '216',
#    'nextStage': '',
#    'ui': {'highlight': False, 'countryChampion': False},
#    'entrant': {'competitorId': '9353',
#     'competitorName': 'Cj Martin',
#     'firstName': 'Cj',
#     'lastName': 'Martin',
#     'status': 'ACT',
#     'postCompStatus': '',
#     'gender': 'M',
#     'profilePicS3key': '600a0-P9353_2-184.jpg',
#     'countryOfOriginCode': '',
#     'countryOfOriginName': '',
#     'countryShortCode': '',
#     'regionId': 'None',
#     'regionName': '',
#     'divisionId': '1',
#     'affiliateId': 'None',
#     'affiliateName': '',
#     'age': '29',
#     'height': '67 in',
#     'weight': '155 lb',
#     'teamCaptain': '0'},
#    'scores': [{'ordinal': 1,
#      'rank': '22',
#      'score': '71',
#      'valid': '1',
#      'scoreDisplay': 'Rnd 5 21 Pullups',
#      'scoreIdentifier': '546f21f4544efefaf470',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '71 pts'},
#     {'ordinal': 2,
#      'rank': '13',
#      'score': '80',
#      'valid': '1',
#      'scoreDisplay': '24:45',
#      'scoreIdentifier': '41e96a5bf7e295be0b6b',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '80 pts'},
#     {'ordinal': 3,
#      'rank': '28',
#      'score': '65',
#      'valid': '1',
#      'scoreDisplay': '710 lb',
#      'scoreIdentifier': '6208e3b164370ea5bd56',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '65 pts'}]},
#   {'overallRank': '21',
#    'overallScore': '215',
#    'nextStage': '',
#    'ui': {'highlight': False, 'countryChampion': False},
#    'entrant': {'competitorId': '1281689',
#     'competitorName': 'Nate Pierce',
#     'firstName': 'Nate',
#     'lastName': 'Pierce',
#     'status': 'ACT',
#     'postCompStatus': '',
#     'gender': 'M',
#     'profilePicS3key': 'men-square.jpg',
#     'countryOfOriginCode': '',
#     'countryOfOriginName': '',
#     'countryShortCode': '',
#     'regionId': 'None',
#     'regionName': '',
#     'divisionId': '1',
#     'affiliateId': 'None',
#     'affiliateName': '',
#     'age': '23',
#     'height': '73 in',
#     'weight': '195 lb',
#     'teamCaptain': '0'},
#    'scores': [{'ordinal': 1,
#      'rank': '27',
#      'score': '66',
#      'valid': '1',
#      'scoreDisplay': 'Rnd 4 19 Pullups',
#      'scoreIdentifier': '6cef0f7d632b2ec9c266',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '66 pts'},
#     {'ordinal': 2,
#      'rank': '19',
#      'score': '74',
#      'valid': '1',
#      'scoreDisplay': '25:54',
#      'scoreIdentifier': 'd6f1d006c7953848469c',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '74 pts'},
#     {'ordinal': 3,
#      'rank': '18',
#      'score': '75',
#      'valid': '1',
#      'scoreDisplay': '840 lb',
#      'scoreIdentifier': '0fb0722dcffb59be1a88',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '75 pts'}]},
#   {'overallRank': '22',
#    'overallScore': '212',
#    'nextStage': '',
#    'ui': {'highlight': False, 'countryChampion': False},
#    'entrant': {'competitorId': '2377129',
#     'competitorName': 'Andreas De',
#     'firstName': 'Andreas',
#     'lastName': 'De',
#     'status': 'ACT',
#     'postCompStatus': '',
#     'gender': 'M',
#     'profilePicS3key': 'men-square.jpg',
#     'countryOfOriginCode': '',
#     'countryOfOriginName': '',
#     'countryShortCode': '',
#     'regionId': 'None',
#     'regionName': '',
#     'divisionId': '1',
#     'affiliateId': 'None',
#     'affiliateName': '',
#     'age': '0',
#     'height': '',
#     'weight': '',
#     'teamCaptain': '0'},
#    'scores': [{'ordinal': 1,
#      'rank': '20',
#      'score': '73',
#      'valid': '1',
#      'scoreDisplay': 'Rnd 5 22 Pullups',
#      'scoreIdentifier': 'dbbe3c4134e599b73952',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '73 pts'},
#     {'ordinal': 2,
#      'rank': '24',
#      'score': '69',
#      'valid': '1',
#      'scoreDisplay': '26:41',
#      'scoreIdentifier': '7cd3639f0930392126dd',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '69 pts'},
#     {'ordinal': 3,
#      'rank': '23',
#      'score': '70',
#      'valid': '1',
#      'scoreDisplay': '755 lb',
#      'scoreIdentifier': 'b10c172fe2a80a536091',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '70 pts'}]},
#   {'overallRank': '23',
#    'overallScore': '206',
#    'nextStage': '',
#    'ui': {'highlight': False, 'countryChampion': False},
#    'entrant': {'competitorId': '704718',
#     'competitorName': 'David Shanahan',
#     'firstName': 'David',
#     'lastName': 'Shanahan',
#     'status': 'ACT',
#     'postCompStatus': '',
#     'gender': 'M',
#     'profilePicS3key': 'men-square.jpg',
#     'countryOfOriginCode': '',
#     'countryOfOriginName': '',
#     'countryShortCode': '',
#     'regionId': 'None',
#     'regionName': '',
#     'divisionId': '1',
#     'affiliateId': 'None',
#     'affiliateName': '',
#     'age': '16',
#     'height': '',
#     'weight': '',
#     'teamCaptain': '0'},
#    'scores': [{'ordinal': 1,
#      'rank': '29',
#      'score': '64',
#      'valid': '1',
#      'scoreDisplay': 'Rnd 3 25 Pullups',
#      'scoreIdentifier': 'bbe8be3dfe7a1d8fbd15',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '64 pts'},
#     {'ordinal': 2,
#      'rank': '14',
#      'score': '79',
#      'valid': '1',
#      'scoreDisplay': '25:04',
#      'scoreIdentifier': 'a911436bd926cb14b081',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '79 pts'},
#     {'ordinal': 3,
#      'rank': '30',
#      'score': '63',
#      'valid': '1',
#      'scoreDisplay': '660 lb',
#      'scoreIdentifier': 'bc52c269fd983d267f03',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '63 pts'}]},
#   {'overallRank': '24',
#    'overallScore': '205',
#    'nextStage': '',
#    'ui': {'highlight': False, 'countryChampion': False},
#    'entrant': {'competitorId': '13119',
#     'competitorName': 'Mark Rosen',
#     'firstName': 'Mark',
#     'lastName': 'Rosen',
#     'status': 'ACT',
#     'postCompStatus': '',
#     'gender': 'M',
#     'profilePicS3key': 'b9dc3-P13119_2-184.jpg',
#     'countryOfOriginCode': '',
#     'countryOfOriginName': '',
#     'countryShortCode': '',
#     'regionId': 'None',
#     'regionName': '',
#     'divisionId': '1',
#     'affiliateId': 'None',
#     'affiliateName': '',
#     'age': '46',
#     'height': '69 in',
#     'weight': '175 lb',
#     'teamCaptain': '0'},
#    'scores': [{'ordinal': 1,
#      'rank': '18',
#      'score': '75',
#      'valid': '1',
#      'scoreDisplay': 'Rnd 5 3 jerks',
#      'scoreIdentifier': '5429ce8a98f2c4bd8070',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '75 pts'},
#     {'ordinal': 2,
#      'rank': '35',
#      'score': '58',
#      'valid': '1',
#      'scoreDisplay': '29:22',
#      'scoreIdentifier': '68110a2528f0c9e1d073',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '58 pts'},
#     {'ordinal': 3,
#      'rank': '21',
#      'score': '72',
#      'valid': '1',
#      'scoreDisplay': '770 lb',
#      'scoreIdentifier': '6621143b24b5cfd5d6c8',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '72 pts'}]},
#   {'overallRank': '25',
#    'overallScore': '205',
#    'nextStage': '',
#    'ui': {'highlight': False, 'countryChampion': False},
#    'entrant': {'competitorId': '2377130',
#     'competitorName': 'Nickolas Hawks',
#     'firstName': 'Nickolas',
#     'lastName': 'Hawks',
#     'status': 'ACT',
#     'postCompStatus': '',
#     'gender': 'M',
#     'profilePicS3key': 'men-square.jpg',
#     'countryOfOriginCode': '',
#     'countryOfOriginName': '',
#     'countryShortCode': '',
#     'regionId': 'None',
#     'regionName': '',
#     'divisionId': '1',
#     'affiliateId': 'None',
#     'affiliateName': '',
#     'age': '0',
#     'height': '',
#     'weight': '',
#     'teamCaptain': '0'},
#    'scores': [{'ordinal': 1,
#      'rank': '33',
#      'score': '60',
#      'valid': '1',
#      'scoreDisplay': '18:14 95 #',
#      'scoreIdentifier': 'cd363e139985e38b4666',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '60 pts'},
#     {'ordinal': 2,
#      'rank': '6',
#      'score': '87',
#      'valid': '1',
#      'scoreDisplay': '23:51',
#      'scoreIdentifier': 'e13d3feba6058266b9e9',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '87 pts'},
#     {'ordinal': 3,
#      'rank': '35',
#      'score': '58',
#      'valid': '1',
#      'scoreDisplay': '535 lb',
#      'scoreIdentifier': '2f0cd9790fb410f7e301',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '58 pts'}]},
#   {'overallRank': '26',
#    'overallScore': '197',
#    'nextStage': '',
#    'ui': {'highlight': False, 'countryChampion': False},
#    'entrant': {'competitorId': '2377131',
#     'competitorName': 'Taylor Nigh',
#     'firstName': 'Taylor',
#     'lastName': 'Nigh',
#     'status': 'ACT',
#     'postCompStatus': '',
#     'gender': 'M',
#     'profilePicS3key': 'men-square.jpg',
#     'countryOfOriginCode': '',
#     'countryOfOriginName': '',
#     'countryShortCode': '',
#     'regionId': 'None',
#     'regionName': '',
#     'divisionId': '1',
#     'affiliateId': 'None',
#     'affiliateName': '',
#     'age': '0',
#     'height': '',
#     'weight': '',
#     'teamCaptain': '0'},
#    'scores': [{'ordinal': 1,
#      'rank': '32',
#      'score': '61',
#      'valid': '1',
#      'scoreDisplay': 'Rnd 2 25 Pullups',
#      'scoreIdentifier': '11f7f38de0a9050ca965',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '61 pts'},
#     {'ordinal': 2,
#      'rank': '21',
#      'score': '72',
#      'valid': '1',
#      'scoreDisplay': '26:16',
#      'scoreIdentifier': '105f3cdea40d7411e832',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '72 pts'},
#     {'ordinal': 3,
#      'rank': '29',
#      'score': '64',
#      'valid': '1',
#      'scoreDisplay': '675 lb',
#      'scoreIdentifier': '6958572d2570dfb9c98e',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '64 pts'}]},
#   {'overallRank': '27',
#    'overallScore': '196',
#    'nextStage': '',
#    'ui': {'highlight': False, 'countryChampion': False},
#    'entrant': {'competitorId': '2377132',
#     'competitorName': 'Steve Serrano',
#     'firstName': 'Steve',
#     'lastName': 'Serrano',
#     'status': 'ACT',
#     'postCompStatus': '',
#     'gender': 'M',
#     'profilePicS3key': 'men-square.jpg',
#     'countryOfOriginCode': '',
#     'countryOfOriginName': '',
#     'countryShortCode': '',
#     'regionId': 'None',
#     'regionName': '',
#     'divisionId': '1',
#     'affiliateId': 'None',
#     'affiliateName': '',
#     'age': '0',
#     'height': '',
#     'weight': '',
#     'teamCaptain': '0'},
#    'scores': [{'ordinal': 1,
#      'rank': '26',
#      'score': '67',
#      'valid': '1',
#      'scoreDisplay': 'Rnd 4 24 Pullups',
#      'scoreIdentifier': 'ba75c4ec20fb6cf8b8b2',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '67 pts'},
#     {'ordinal': 2,
#      'rank': '40',
#      'score': '53',
#      'valid': '1',
#      'scoreDisplay': '34:10',
#      'scoreIdentifier': '4d77a023eae67f980616',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '53 pts'},
#     {'ordinal': 3,
#      'rank': '17',
#      'score': '76',
#      'valid': '1',
#      'scoreDisplay': '850 lb',
#      'scoreIdentifier': '9ee97b12e62ff10a5aa0',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '76 pts'}]},
#   {'overallRank': '28',
#    'overallScore': '195',
#    'nextStage': '',
#    'ui': {'highlight': False, 'countryChampion': False},
#    'entrant': {'competitorId': '2377133',
#     'competitorName': 'Michael Woodruff',
#     'firstName': 'Michael',
#     'lastName': 'Woodruff',
#     'status': 'ACT',
#     'postCompStatus': '',
#     'gender': 'M',
#     'profilePicS3key': 'men-square.jpg',
#     'countryOfOriginCode': '',
#     'countryOfOriginName': '',
#     'countryShortCode': '',
#     'regionId': 'None',
#     'regionName': '',
#     'divisionId': '1',
#     'affiliateId': 'None',
#     'affiliateName': '',
#     'age': '0',
#     'height': '',
#     'weight': '',
#     'teamCaptain': '0'},
#    'scores': [{'ordinal': 1,
#      'rank': '28',
#      'score': '65',
#      'valid': '1',
#      'scoreDisplay': 'Rnd 4 5 Pullups',
#      'scoreIdentifier': '8c05c8df9fca3541f5e2',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '65 pts'},
#     {'ordinal': 2,
#      'rank': '29',
#      'score': '64',
#      'valid': '1',
#      'scoreDisplay': '27:29',
#      'scoreIdentifier': '521d11628b8f1260e72e',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '64 pts'},
#     {'ordinal': 3,
#      'rank': '27',
#      'score': '66',
#      'valid': '1',
#      'scoreDisplay': '715 lb',
#      'scoreIdentifier': '7cc5b39f2de15c579596',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '66 pts'}]},
#   {'overallRank': '29',
#    'overallScore': '190',
#    'nextStage': '',
#    'ui': {'highlight': False, 'countryChampion': False},
#    'entrant': {'competitorId': '2377134',
#     'competitorName': 'Eric Le',
#     'firstName': 'Eric',
#     'lastName': 'Le',
#     'status': 'ACT',
#     'postCompStatus': '',
#     'gender': 'M',
#     'profilePicS3key': 'men-square.jpg',
#     'countryOfOriginCode': '',
#     'countryOfOriginName': '',
#     'countryShortCode': '',
#     'regionId': 'None',
#     'regionName': '',
#     'divisionId': '1',
#     'affiliateId': 'None',
#     'affiliateName': '',
#     'age': '0',
#     'height': '',
#     'weight': '',
#     'teamCaptain': '0'},
#    'scores': [{'ordinal': 1,
#      'rank': '36',
#      'score': '57',
#      'valid': '1',
#      'scoreDisplay': 'Rnd 4 25 Pullups 95#',
#      'scoreIdentifier': '76a6fbbb0fa196bfd6d3',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '57 pts'},
#     {'ordinal': 2,
#      'rank': '20',
#      'score': '73',
#      'valid': '1',
#      'scoreDisplay': '26:15',
#      'scoreIdentifier': '2e081b2f4bbf8beef5bd',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '73 pts'},
#     {'ordinal': 3,
#      'rank': '33',
#      'score': '60',
#      'valid': '1',
#      'scoreDisplay': '645 lb',
#      'scoreIdentifier': '779dc086684536fe2aff',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '60 pts'}]},
#   {'overallRank': '30',
#    'overallScore': '185',
#    'nextStage': '',
#    'ui': {'highlight': False, 'countryChampion': False},
#    'entrant': {'competitorId': '36670',
#     'competitorName': 'John Kane',
#     'firstName': 'John',
#     'lastName': 'Kane',
#     'status': 'ACT',
#     'postCompStatus': '',
#     'gender': 'M',
#     'profilePicS3key': 'eff4c-P36670_8-184.jpg',
#     'countryOfOriginCode': '',
#     'countryOfOriginName': '',
#     'countryShortCode': '',
#     'regionId': 'None',
#     'regionName': '',
#     'divisionId': '1',
#     'affiliateId': 'None',
#     'affiliateName': '',
#     'age': '54',
#     'height': '67 in',
#     'weight': '176 lb',
#     'teamCaptain': '0'},
#    'scores': [{'ordinal': 1,
#      'rank': '37',
#      'score': '56',
#      'valid': '1',
#      'scoreDisplay': 'Rnd 4 5 Push Jerks Jumping Pullups',
#      'scoreIdentifier': 'f8612ac6daeb7df319d9',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '56 pts'},
#     {'ordinal': 2,
#      'rank': '33',
#      'score': '60',
#      'valid': '1',
#      'scoreDisplay': '28:55',
#      'scoreIdentifier': '487a8332dad1b10c72b9',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '60 pts'},
#     {'ordinal': 3,
#      'rank': '24',
#      'score': '69',
#      'valid': '1',
#      'scoreDisplay': '745 lb',
#      'scoreIdentifier': '26c4f0391cde7fd8eb00',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '69 pts'}]},
#   {'overallRank': '31',
#    'overallScore': '184',
#    'nextStage': '',
#    'ui': {'highlight': False, 'countryChampion': False},
#    'entrant': {'competitorId': '2377135',
#     'competitorName': 'Thomas Silva',
#     'firstName': 'Thomas',
#     'lastName': 'Silva',
#     'status': 'ACT',
#     'postCompStatus': '',
#     'gender': 'M',
#     'profilePicS3key': 'men-square.jpg',
#     'countryOfOriginCode': '',
#     'countryOfOriginName': '',
#     'countryShortCode': '',
#     'regionId': 'None',
#     'regionName': '',
#     'divisionId': '1',
#     'affiliateId': 'None',
#     'affiliateName': '',
#     'age': '0',
#     'height': '',
#     'weight': '',
#     'teamCaptain': '0'},
#    'scores': [{'ordinal': 1,
#      'rank': '39',
#      'score': '54',
#      'valid': '1',
#      'scoreDisplay': '14:46 Jumping Pullups 95#',
#      'scoreIdentifier': '0f3a55341b0c77d44323',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
# ...
#      'scoreIdentifier': '31eace49dfa6158122fe',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '58 pts'},
#     {'ordinal': 2,
#      'rank': '37',
#      'score': '56',
#      'valid': '1',
#      'scoreDisplay': '30:46',
#      'scoreIdentifier': 'e00c639a649ab1f7b6dd',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '56 pts'},
#     {'ordinal': 3,
#      'rank': '32',
#      'score': '61',
#      'valid': '1',
#      'scoreDisplay': '650 lb',
#      'scoreIdentifier': 'a27d9d38988e347b7f49',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '61 pts'}]},
#   {'overallRank': '35',
#    'overallScore': '163',
#    'nextStage': '',
#    'ui': {'highlight': False, 'countryChampion': False},
#    'entrant': {'competitorId': '2377136',
#     'competitorName': 'Keith Ansell',
#     'firstName': 'Keith',
#     'lastName': 'Ansell',
#     'status': 'ACT',
#     'postCompStatus': '',
#     'gender': 'M',
#     'profilePicS3key': 'men-square.jpg',
#     'countryOfOriginCode': '',
#     'countryOfOriginName': '',
#     'countryShortCode': '',
#     'regionId': 'None',
#     'regionName': '',
#     'divisionId': '1',
#     'affiliateId': 'None',
#     'affiliateName': '',
#     'age': '0',
#     'height': '',
#     'weight': '',
#     'teamCaptain': '0'},
#    'scores': [{'ordinal': 1,
#      'rank': '41',
#      'score': '52',
#      'valid': '1',
#      'scoreDisplay': '14:24 Jumping Pullups 75#',
#      'scoreIdentifier': '2fce73edb46038512571',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '52 pts'},
#     {'ordinal': 2,
#      'rank': '39',
#      'score': '54',
#      'valid': '1',
#      'scoreDisplay': '32:44',
#      'scoreIdentifier': '8cbe0fe748151e4eead6',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '54 pts'},
#     {'ordinal': 3,
#      'rank': '36',
#      'score': '57',
#      'valid': '1',
#      'scoreDisplay': '385 lb',
#      'scoreIdentifier': '521e21af232c02af86be',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '57 pts'}]},
#   {'overallRank': '36',
#    'overallScore': '175',
#    'nextStage': '',
#    'ui': {'highlight': False, 'countryChampion': False},
#    'entrant': {'competitorId': '2377137',
#     'competitorName': 'Kris Ratz',
#     'firstName': 'Kris',
#     'lastName': 'Ratz',
#     'status': 'WD',
#     'postCompStatus': '',
#     'gender': 'M',
#     'profilePicS3key': 'men-square.jpg',
#     'countryOfOriginCode': '',
#     'countryOfOriginName': '',
#     'countryShortCode': '',
#     'regionId': 'None',
#     'regionName': '',
#     'divisionId': '1',
#     'affiliateId': 'None',
#     'affiliateName': '',
#     'age': '0',
#     'height': '',
#     'weight': '',
#     'teamCaptain': '0'},
#    'scores': [{'ordinal': 1,
#      'rank': '6',
#      'score': '87',
#      'valid': '1',
#      'scoreDisplay': '16:12',
#      'scoreIdentifier': '0df763eb5dcc5be04f50',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '87 pts'},
#     {'ordinal': 2,
#      'rank': '5',
#      'score': '88',
#      'valid': '1',
#      'scoreDisplay': '22:10',
#      'scoreIdentifier': 'dd0eb34066c4565ea688',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '88 pts'},
#     {'ordinal': 3,
#      'rank': 'WD',
#      'score': '0',
#      'valid': '',
#      'scoreDisplay': '',
#      'scoreIdentifier': '1e12e660453ed44d0629',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': ''}]},
#   {'overallRank': '37',
#    'overallScore': '163',
#    'nextStage': '',
#    'ui': {'highlight': False, 'countryChampion': False},
#    'entrant': {'competitorId': '15679',
#     'competitorName': 'Brandon Banks',
#     'firstName': 'Brandon',
#     'lastName': 'Banks',
#     'status': 'WD',
#     'postCompStatus': '',
#     'gender': 'M',
#     'profilePicS3key': 'men-square.jpg',
#     'countryOfOriginCode': '',
#     'countryOfOriginName': '',
#     'countryShortCode': '',
#     'regionId': 'None',
#     'regionName': '',
#     'divisionId': '1',
#     'affiliateId': 'None',
#     'affiliateName': '',
#     'age': '31',
#     'height': '8 in',
#     'weight': '185 lb',
#     'teamCaptain': '0'},
#    'scores': [{'ordinal': 1,
#      'rank': '15',
#      'score': '78',
#      'valid': '1',
#      'scoreDisplay': '18:40',
#      'scoreIdentifier': '6d13425bc7fe51cac13a',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '78 pts'},
#     {'ordinal': 2,
#      'rank': '8',
#      'score': '85',
#      'valid': '1',
#      'scoreDisplay': '23:56',
#      'scoreIdentifier': '128fbb79ba33ba46369a',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '85 pts'},
#     {'ordinal': 3,
#      'rank': 'WD',
#      'score': '0',
#      'valid': '',
#      'scoreDisplay': '',
#      'scoreIdentifier': 'ded85f16d65c24a63067',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': ''}]},
#   {'overallRank': '38',
#    'overallScore': '158',
#    'nextStage': '',
#    'ui': {'highlight': False, 'countryChampion': False},
#    'entrant': {'competitorId': '218478',
#     'competitorName': 'Andy Stumpf',
#     'firstName': 'Andy',
#     'lastName': 'Stumpf',
#     'status': 'WD',
#     'postCompStatus': '',
#     'gender': 'M',
#     'profilePicS3key': 'men-square.jpg',
#     'countryOfOriginCode': '',
#     'countryOfOriginName': '',
#     'countryShortCode': '',
#     'regionId': 'None',
#     'regionName': '',
#     'divisionId': '1',
#     'affiliateId': 'None',
#     'affiliateName': '',
#     'age': '29',
#     'height': '',
#     'weight': '',
#     'teamCaptain': '0'},
#    'scores': [{'ordinal': 1,
#      'rank': '10',
#      'score': '83',
#      'valid': '1',
#      'scoreDisplay': '17:26',
#      'scoreIdentifier': 'b9512e2ea3d48902374a',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '83 pts'},
#     {'ordinal': 2,
#      'rank': '18',
#      'score': '75',
#      'valid': '1',
#      'scoreDisplay': '25:49',
#      'scoreIdentifier': 'fb543ef20bc348844250',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '75 pts'},
#     {'ordinal': 3,
#      'rank': 'WD',
#      'score': '0',
#      'valid': '',
#      'scoreDisplay': '',
#      'scoreIdentifier': '4da67169f3bd8a0dfb67',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': ''}]},
#   {'overallRank': '39',
#    'overallScore': '121',
#    'nextStage': '',
#    'ui': {'highlight': False, 'countryChampion': False},
#    'entrant': {'competitorId': '41231',
#     'competitorName': 'Saul Jimenez',
#     'firstName': 'Saul',
#     'lastName': 'Jimenez',
#     'status': 'WD',
#     'postCompStatus': '',
#     'gender': 'M',
#     'profilePicS3key': 'men-square.jpg',
#     'countryOfOriginCode': '',
#     'countryOfOriginName': '',
#     'countryShortCode': '',
#     'regionId': 'None',
#     'regionName': '',
#     'divisionId': '1',
#     'affiliateId': 'None',
#     'affiliateName': '',
#     'age': '45',
#     'height': '67 in',
#     'weight': '175 lb',
#     'teamCaptain': '0'},
#    'scores': [{'ordinal': 1,
#      'rank': '38',
#      'score': '55',
#      'valid': '1',
#      'scoreDisplay': '19:28 Jumping Pullups',
#      'scoreIdentifier': '0cc37415103c753d7ddd',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '55 pts'},
#     {'ordinal': 2,
#      'rank': '27',
#      'score': '66',
#      'valid': '1',
#      'scoreDisplay': '27:25',
#      'scoreIdentifier': 'f5ef3f26dab5d070eeb7',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '66 pts'},
#     {'ordinal': 3,
#      'rank': 'WD',
#      'score': '0',
#      'valid': '',
#      'scoreDisplay': '',
#      'scoreIdentifier': '9b021a34919e8f353279',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': ''}]},
#   {'overallRank': '40',
#    'overallScore': '85',
#    'nextStage': '',
#    'ui': {'highlight': False, 'countryChampion': False},
#    'entrant': {'competitorId': '97943',
#     'competitorName': 'Zac Pine',
#     'firstName': 'Zac',
#     'lastName': 'Pine',
#     'status': 'WD',
#     'postCompStatus': '',
#     'gender': 'M',
#     'profilePicS3key': '57853-P97943_2-184.jpg',
#     'countryOfOriginCode': '',
#     'countryOfOriginName': '',
#     'countryShortCode': '',
#     'regionId': 'None',
#     'regionName': '',
#     'divisionId': '1',
#     'affiliateId': 'None',
#     'affiliateName': '',
#     'age': '26',
#     'height': '69 in',
#     'weight': '170 lb',
#     'teamCaptain': '0'},
#    'scores': [{'ordinal': 1,
#      'rank': '8',
#      'score': '85',
#      'valid': '1',
#      'scoreDisplay': '16:55',
#      'scoreIdentifier': 'e8c419e6f77845834686',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '85 pts'},
#     {'ordinal': 2,
#      'rank': 'WD',
#      'score': '0',
#      'valid': '',
#      'scoreDisplay': '',
#      'scoreIdentifier': 'b5d202e260d7348cdafa',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': ''},
#     {'ordinal': 3,
#      'rank': 'WD',
#      'score': '0',
#      'valid': '',
#      'scoreDisplay': '',
#      'scoreIdentifier': '0ba6049a944fcce58aa1',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': ''}]},
#   {'overallRank': '41',
#    'overallScore': '59',
#    'nextStage': '',
#    'ui': {'highlight': False, 'countryChampion': False},
#    'entrant': {'competitorId': '82637',
#     'competitorName': 'Russell Bruel',
#     'firstName': 'Russell',
#     'lastName': 'Bruel',
#     'status': 'WD',
#     'postCompStatus': '',
#     'gender': 'M',
#     'profilePicS3key': '6eb48-P82637_1-184.jpg',
#     'countryOfOriginCode': '',
#     'countryOfOriginName': '',
#     'countryShortCode': '',
#     'regionId': 'None',
#     'regionName': '',
#     'divisionId': '1',
#     'affiliateId': 'None',
#     'affiliateName': '',
#     'age': '31',
#     'height': '63 in',
#     'weight': '142 lb',
#     'teamCaptain': '0'},
#    'scores': [{'ordinal': 1,
#      'rank': '34',
#      'score': '59',
#      'valid': '1',
#      'scoreDisplay': '19:29 95#',
#      'scoreIdentifier': 'f8f23b7efe9b383e4f9e',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '59 pts'},
#     {'ordinal': 2,
#      'rank': 'WD',
#      'score': '0',
#      'valid': '',
#      'scoreDisplay': '',
#      'scoreIdentifier': 'b1d3af004d42034d9e2b',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': ''},
#     {'ordinal': 3,
#      'rank': 'WD',
#      'score': '0',
#      'valid': '',
#      'scoreDisplay': '',
#      'scoreIdentifier': 'b389d0b9e1d8c4373abb',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': ''}]},
#   {'overallRank': '42',
#    'overallScore': '84',
#    'nextStage': '',
#    'ui': {'highlight': False, 'countryChampion': False},
#    'entrant': {'competitorId': '2377138',
#     'competitorName': 'John Murphy',
#     'firstName': 'John',
#     'lastName': 'Murphy',
#     'status': 'WD',
#     'postCompStatus': '',
#     'gender': 'M',
#     'profilePicS3key': 'men-square.jpg',
#     'countryOfOriginCode': '',
#     'countryOfOriginName': '',
#     'countryShortCode': '',
#     'regionId': 'None',
#     'regionName': '',
#     'divisionId': '1',
#     'affiliateId': 'None',
#     'affiliateName': '',
#     'age': '0',
#     'height': '',
#     'weight': '',
#     'teamCaptain': '0'},
#    'scores': [{'ordinal': 1,
#      'rank': 'WD',
#      'score': '0',
#      'valid': '',
#      'scoreDisplay': '',
#      'scoreIdentifier': '3986e64c631144c2e51b',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': ''},
#     {'ordinal': 2,
#      'rank': '9',
#      'score': '84',
#      'valid': '1',
#      'scoreDisplay': '23:56',
#      'scoreIdentifier': 'eb858cfb1912700936d4',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '84 pts'},
#     {'ordinal': 3,
#      'rank': 'WD',
#      'score': '0',
#      'valid': '',
#      'scoreDisplay': '',
#      'scoreIdentifier': '009e40bd7b72398d9446',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': ''}]},
#   {'overallRank': '43',
#    'overallScore': '85',
#    'nextStage': '',
#    'ui': {'highlight': False, 'countryChampion': False},
#    'entrant': {'competitorId': '2377139',
#     'competitorName': 'Jacob Typskin',
#     'firstName': 'Jacob',
#     'lastName': 'Typskin',
#     'status': 'WD',
#     'postCompStatus': '',
#     'gender': 'M',
#     'profilePicS3key': 'men-square.jpg',
#     'countryOfOriginCode': '',
#     'countryOfOriginName': '',
#     'countryShortCode': '',
#     'regionId': 'None',
#     'regionName': '',
#     'divisionId': '1',
#     'affiliateId': 'None',
#     'affiliateName': '',
#     'age': '0',
#     'height': '',
#     'weight': '',
#     'teamCaptain': '0'},
#    'scores': [{'ordinal': 1,
#      'rank': 'WD',
#      'score': '0',
#      'valid': '',
#      'scoreDisplay': '',
#      'scoreIdentifier': 'd8eb7f0151186f915ba0',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': ''},
#     {'ordinal': 2,
#      'rank': 'WD',
#      'score': '0',
#      'valid': '',
#      'scoreDisplay': '',
#      'scoreIdentifier': '7eee9d33d1eb8914b2d3',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': ''},
#     {'ordinal': 3,
#      'rank': '8',
#      'score': '85',
#      'valid': '1',
#      'scoreDisplay': '915 lb',
#      'scoreIdentifier': '14b08960e9cacfbf273e',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '85 pts'}]},
#   {'overallRank': '44',
#    'overallScore': '56',
#    'nextStage': '',
#    'ui': {'highlight': False, 'countryChampion': False},
#    'entrant': {'competitorId': '27667',
#     'competitorName': 'Keegan Martin',
#     'firstName': 'Keegan',
#     'lastName': 'Martin',
#     'status': 'WD',
#     'postCompStatus': '',
#     'gender': 'M',
#     'profilePicS3key': '0aafa-P27667_2-184.jpg',
#     'countryOfOriginCode': '',
#     'countryOfOriginName': '',
#     'countryShortCode': '',
#     'regionId': 'None',
#     'regionName': '',
#     'divisionId': '1',
#     'affiliateId': 'None',
#     'affiliateName': '',
#     'age': '13',
#     'height': '71 in',
#     'weight': '182 lb',
#     'teamCaptain': '0'},
#    'scores': [{'ordinal': 1,
#      'rank': 'WD',
#      'score': '0',
#      'valid': '',
#      'scoreDisplay': '',
#      'scoreIdentifier': '003d17901fefffff227f',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': ''},
#     {'ordinal': 2,
#      'rank': 'WD',
#      'score': '0',
#      'valid': '',
#      'scoreDisplay': '',
#      'scoreIdentifier': '56a471f3a4a1bfb993db',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': ''},
#     {'ordinal': 3,
#      'rank': '37',
#      'score': '56',
#      'valid': '1',
#      'scoreDisplay': '360 lb',
#      'scoreIdentifier': '1408d10ce49a5eed5e1b',
#      'mobileScoreDisplay': '',
#      'scaled': '0',
#      'video': '0',
#      'heat': '',
#      'lane': '',
#      'breakdown': '56 pts'}]}]}

# %% [markdown]
# ### Calling the api for info on multiple Games and writing the results to a csv

# %%
timestr = time.strftime("%Y%m%d_%H%M%S")
df_games_info_multiple = games_info_multiple()
file_name = f'games_info_multiple_{timestr}'
df_games_info_multiple.to_csv(f'../data/{file_name}.csv')
# Out:
# 2025-01-01 13:52:59,213 - INFO - Fetching multiple years games info from 2018 to 2022 for division 1
# 2025-01-01 13:52:59,240 - INFO - Processing year 2018 and division 1
# 2025-01-01 13:52:59,241 - INFO - Fetching games info for year 2018 and division 1
# 2025-01-01 13:52:59,242 - INFO - Starting API call for year 2018, division 1 and page 1
# 2025-01-01 13:52:59,724 - INFO - Successfully fetched data for year 2018, division 1 and page 1
# 2025-01-01 13:52:59,727 - INFO - Fetched games metadata: competition_id 31, total_pages 1, total_competitors 40 and total_events 14
# 2025-01-01 13:52:59,732 - INFO - Processing year 2019 and division 1
# 2025-01-01 13:52:59,733 - INFO - Fetching games info for year 2019 and division 1
# 2025-01-01 13:52:59,734 - INFO - Starting API call for year 2019, division 1 and page 1
# 2025-01-01 13:53:00,239 - INFO - Successfully fetched data for year 2019, division 1 and page 1
# 2025-01-01 13:53:00,242 - INFO - Fetched games metadata: competition_id 52, total_pages 3, total_competitors 144 and total_events 12
# 2025-01-01 13:53:00,244 - INFO - Processing year 2020 and division 1
# 2025-01-01 13:53:00,244 - INFO - Fetching games info for year 2020 and division 1
# 2025-01-01 13:53:00,245 - INFO - Starting API call for year 2020, division 1 and page 1
# 2025-01-01 13:53:00,646 - INFO - Successfully fetched data for year 2020, division 1 and page 1
# 2025-01-01 13:53:00,648 - INFO - Fetched games metadata: competition_id 58, total_pages 1, total_competitors 30 and total_events 20
# 2025-01-01 13:53:00,650 - INFO - Processing year 2021 and division 1
# 2025-01-01 13:53:00,651 - INFO - Fetching games info for year 2021 and division 1
# 2025-01-01 13:53:00,651 - INFO - Starting API call for year 2021, division 1 and page 1
# 2025-01-01 13:53:01,104 - INFO - Successfully fetched data for year 2021, division 1 and page 1
# 2025-01-01 13:53:01,108 - INFO - Fetched games metadata: competition_id 161, total_pages 1, total_competitors 40 and total_events 15
# 2025-01-01 13:53:01,109 - INFO - Processing year 2022 and division 1
# 2025-01-01 13:53:01,110 - INFO - Fetching games info for year 2022 and division 1
# 2025-01-01 13:53:01,110 - INFO - Starting API call for year 2022, division 1 and page 1
# 2025-01-01 13:53:01,459 - INFO - Successfully fetched data for year 2022, division 1 and page 1
# 2025-01-01 13:53:01,461 - INFO - Fetched games metadata: competition_id 189, total_pages 1, total_competitors 40 and total_events 14
# 2025-01-01 13:53:01,463 - INFO - Completed fetching games info from 2018 to 2022 for division 1. Total records: 5

# %%
pd.read_csv(f'../data/{file_name}.csv').head()
# Out:
#    Unnamed: 0  competitionId  totalPages  totalCompetitors  totalEvents  year  \
# 0           0             31           1                40           14  2018
# 1           1             52           3               144           12  2019
# 2           2             58           1                30           20  2020
# 3           3            161           1                40           15  2021
# 4           4            189           1                40           14  2022
#
#    division
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1

# %% [markdown]
# ### Calling the api for info on competitors and writing the results to a csv

# %%
timestr = time.strftime("%Y%m%d_%H%M%S")
df_games_info_competitors_multiple = games_info_competitor_multiple(2007, 2024,0)
file_name = f'games_info_competitor_multiple_{timestr}'
df_games_info_competitors_multiple.to_csv(f'../data/{file_name}.csv')
# Out:
# 2025-01-01 13:53:06,016 - INFO - Fetching competitors info from 2007 to 2024 for division 0
# 2025-01-01 13:53:06,018 - INFO - Fetching competitors info 2007 for division 0
# 2025-01-01 13:53:06,019 - INFO - Fetching competitor info for year 2007 and division 0
# 2025-01-01 13:53:06,021 - INFO - Processing division 1
# 2025-01-01 13:53:06,022 - INFO - Fetching games info for year 2007 and division 1
# 2025-01-01 13:53:06,024 - INFO - Starting API call for year 2007, division 1 and page 1
# 2025-01-01 13:53:06,116 - INFO - Successfully fetched data for year 2007, division 1 and page 1
# 2025-01-01 13:53:06,117 - INFO - Fetched games metadata: competition_id 59, total_pages 1, total_competitors 44 and total_events 3
# 2025-01-01 13:53:06,118 - INFO - Fetching page 1 for division 1
# 2025-01-01 13:53:06,119 - INFO - Starting API call for year 2007, division 1 and page 1
# 2025-01-01 13:53:06,209 - INFO - Successfully fetched data for year 2007, division 1 and page 1
# 2025-01-01 13:53:06,265 - INFO - Processing division 2
# 2025-01-01 13:53:06,266 - INFO - Fetching games info for year 2007 and division 2
# 2025-01-01 13:53:06,266 - INFO - Starting API call for year 2007, division 2 and page 1
# 2025-01-01 13:53:06,542 - INFO - Successfully fetched data for year 2007, division 2 and page 1
# 2025-01-01 13:53:06,543 - INFO - Fetched games metadata: competition_id 59, total_pages 1, total_competitors 20 and total_events 3
# 2025-01-01 13:53:06,544 - INFO - Fetching page 1 for division 2
# 2025-01-01 13:53:06,544 - INFO - Starting API call for year 2007, division 2 and page 1
# 2025-01-01 13:53:06,631 - INFO - Successfully fetched data for year 2007, division 2 and page 1
# 2025-01-01 13:53:06,668 - INFO - Fetched competitor info. Total competitors: 64
# 2025-01-01 13:53:06,669 - INFO - Fetching competitors info 2008 for division 0
# 2025-01-01 13:53:06,671 - INFO - Fetching competitor info for year 2008 and division 0
# 2025-01-01 13:53:06,673 - INFO - Processing division 1
# 2025-01-01 13:53:06,674 - INFO - Fetching games info for year 2008 and division 1
# 2025-01-01 13:53:06,674 - INFO - Starting API call for year 2008, division 1 and page 1
# 2025-01-01 13:53:06,964 - INFO - Successfully fetched data for year 2008, division 1 and page 1
# 2025-01-01 13:53:06,966 - INFO - Fetched games metadata: competition_id 60, total_pages 3, total_competitors 119 and total_events 4
# 2025-01-01 13:53:06,967 - INFO - Fetching page 1 for division 1
# 2025-01-01 13:53:06,970 - INFO - Starting API call for year 2008, division 1 and page 1
# 2025-01-01 13:53:07,064 - INFO - Successfully fetched data for year 2008, division 1 and page 1
# 2025-01-01 13:53:07,136 - INFO - Fetching page 2 for division 1
# 2025-01-01 13:53:07,136 - INFO - Starting API call for year 2008, division 1 and page 2
# 2025-01-01 13:53:07,608 - INFO - Successfully fetched data for year 2008, division 1 and page 2
# 2025-01-01 13:53:07,674 - INFO - Fetching page 3 for division 1
# 2025-01-01 13:53:07,674 - INFO - Starting API call for year 2008, division 1 and page 3
# 2025-01-01 13:53:07,996 - INFO - Successfully fetched data for year 2008, division 1 and page 3
# 2025-01-01 13:53:08,028 - INFO - Processing division 2
# 2025-01-01 13:53:08,030 - INFO - Fetching games info for year 2008 and division 2
# 2025-01-01 13:53:08,030 - INFO - Starting API call for year 2008, division 2 and page 1
# 2025-01-01 13:53:08,314 - INFO - Successfully fetched data for year 2008, division 2 and page 1
# 2025-01-01 13:53:08,315 - INFO - Fetched games metadata: competition_id 60, total_pages 1, total_competitors 36 and total_events 4
# 2025-01-01 13:53:08,316 - INFO - Fetching page 1 for division 2
# 2025-01-01 13:53:08,317 - INFO - Starting API call for year 2008, division 2 and page 1
# 2025-01-01 13:53:08,410 - INFO - Successfully fetched data for year 2008, division 2 and page 1
# 2025-01-01 13:53:08,462 - INFO - Fetched competitor info. Total competitors: 155
# 2025-01-01 13:53:08,465 - INFO - Fetching competitors info 2009 for division 0
# 2025-01-01 13:53:08,466 - INFO - Fetching competitor info for year 2009 and division 0
# 2025-01-01 13:53:08,466 - INFO - Processing division 1
# 2025-01-01 13:53:08,467 - INFO - Fetching games info for year 2009 and division 1
# 2025-01-01 13:53:08,467 - INFO - Starting API call for year 2009, division 1 and page 1
# 2025-01-01 13:53:08,787 - INFO - Successfully fetched data for year 2009, division 1 and page 1
# 2025-01-01 13:53:08,789 - INFO - Fetched games metadata: competition_id 61, total_pages 2, total_competitors 74 and total_events 8
# 2025-01-01 13:53:08,790 - INFO - Fetching page 1 for division 1
# 2025-01-01 13:53:08,791 - INFO - Starting API call for year 2009, division 1 and page 1
# 2025-01-01 13:53:08,885 - INFO - Successfully fetched data for year 2009, division 1 and page 1
# 2025-01-01 13:53:08,948 - INFO - Fetching page 2 for division 1
# 2025-01-01 13:53:08,948 - INFO - Starting API call for year 2009, division 1 and page 2
# 2025-01-01 13:53:09,219 - INFO - Successfully fetched data for year 2009, division 1 and page 2
# 2025-01-01 13:53:09,259 - INFO - Processing division 2
# 2025-01-01 13:53:09,260 - INFO - Fetching games info for year 2009 and division 2
# 2025-01-01 13:53:09,260 - INFO - Starting API call for year 2009, division 2 and page 1
# 2025-01-01 13:53:09,561 - INFO - Successfully fetched data for year 2009, division 2 and page 1
# 2025-01-01 13:53:09,563 - INFO - Fetched games metadata: competition_id 61, total_pages 2, total_competitors 72 and total_events 8
# 2025-01-01 13:53:09,564 - INFO - Fetching page 1 for division 2
# 2025-01-01 13:53:09,564 - INFO - Starting API call for year 2009, division 2 and page 1
# 2025-01-01 13:53:09,657 - INFO - Successfully fetched data for year 2009, division 2 and page 1
# 2025-01-01 13:53:09,746 - INFO - Fetching page 2 for division 2
# 2025-01-01 13:53:09,747 - INFO - Starting API call for year 2009, division 2 and page 2
# 2025-01-01 13:53:10,074 - INFO - Successfully fetched data for year 2009, division 2 and page 2
# 2025-01-01 13:53:10,114 - INFO - Fetched competitor info. Total competitors: 146
# 2025-01-01 13:53:10,117 - INFO - Fetching competitors info 2010 for division 0
# 2025-01-01 13:53:10,121 - INFO - Fetching competitor info for year 2010 and division 0
# 2025-01-01 13:53:10,123 - INFO - Processing division 1
# 2025-01-01 13:53:10,126 - INFO - Fetching games info for year 2010 and division 1
# 2025-01-01 13:53:10,127 - INFO - Starting API call for year 2010, division 1 and page 1
# 2025-01-01 13:53:10,443 - INFO - Successfully fetched data for year 2010, division 1 and page 1
# 2025-01-01 13:53:10,446 - INFO - Fetched games metadata: competition_id 62, total_pages 1, total_competitors 45 and total_events 9
# 2025-01-01 13:53:10,446 - INFO - Fetching page 1 for division 1
# 2025-01-01 13:53:10,447 - INFO - Starting API call for year 2010, division 1 and page 1
# 2025-01-01 13:53:10,539 - INFO - Successfully fetched data for year 2010, division 1 and page 1
# 2025-01-01 13:53:10,595 - INFO - Processing division 2
# 2025-01-01 13:53:10,595 - INFO - Fetching games info for year 2010 and division 2
# 2025-01-01 13:53:10,596 - INFO - Starting API call for year 2010, division 2 and page 1
# 2025-01-01 13:53:11,088 - INFO - Successfully fetched data for year 2010, division 2 and page 1
# 2025-01-01 13:53:11,090 - INFO - Fetched games metadata: competition_id 62, total_pages 1, total_competitors 45 and total_events 9
# 2025-01-01 13:53:11,091 - INFO - Fetching page 1 for division 2
# 2025-01-01 13:53:11,091 - INFO - Starting API call for year 2010, division 2 and page 1
# 2025-01-01 13:53:11,192 - INFO - Successfully fetched data for year 2010, division 2 and page 1
# 2025-01-01 13:53:11,254 - INFO - Fetched competitor info. Total competitors: 90
# 2025-01-01 13:53:11,257 - INFO - Fetching competitors info 2011 for division 0
# 2025-01-01 13:53:11,258 - INFO - Fetching competitor info for year 2011 and division 0
# 2025-01-01 13:53:11,259 - INFO - Processing division 1
# 2025-01-01 13:53:11,259 - INFO - Fetching games info for year 2011 and division 1
# 2025-01-01 13:53:11,260 - INFO - Starting API call for year 2011, division 1 and page 1
# 2025-01-01 13:53:11,586 - INFO - Successfully fetched data for year 2011, division 1 and page 1
# 2025-01-01 13:53:11,589 - INFO - Fetched games metadata: competition_id 63, total_pages 1, total_competitors 49 and total_events 10
# 2025-01-01 13:53:11,590 - INFO - Fetching page 1 for division 1
# 2025-01-01 13:53:11,591 - INFO - Starting API call for year 2011, division 1 and page 1
# 2025-01-01 13:53:11,688 - INFO - Successfully fetched data for year 2011, division 1 and page 1
# 2025-01-01 13:53:11,761 - INFO - Processing division 2
# 2025-01-01 13:53:11,761 - INFO - Fetching games info for year 2011 and division 2
# 2025-01-01 13:53:11,762 - INFO - Starting API call for year 2011, division 2 and page 1
# 2025-01-01 13:53:12,217 - INFO - Successfully fetched data for year 2011, division 2 and page 1
# 2025-01-01 13:53:12,220 - INFO - Fetched games metadata: competition_id 63, total_pages 1, total_competitors 47 and total_events 10
# 2025-01-01 13:53:12,221 - INFO - Fetching page 1 for division 2
# 2025-01-01 13:53:12,222 - INFO - Starting API call for year 2011, division 2 and page 1
# 2025-01-01 13:53:12,318 - INFO - Successfully fetched data for year 2011, division 2 and page 1
# 2025-01-01 13:53:12,386 - INFO - Fetched competitor info. Total competitors: 96
# 2025-01-01 13:53:12,389 - INFO - Fetching competitors info 2012 for division 0
# 2025-01-01 13:53:12,389 - INFO - Fetching competitor info for year 2012 and division 0
# 2025-01-01 13:53:12,390 - INFO - Processing division 1
# 2025-01-01 13:53:12,391 - INFO - Fetching games info for year 2012 and division 1
# 2025-01-01 13:53:12,391 - INFO - Starting API call for year 2012, division 1 and page 1
# 2025-01-01 13:53:12,830 - INFO - Successfully fetched data for year 2012, division 1 and page 1
# 2025-01-01 13:53:12,834 - INFO - Fetched games metadata: competition_id 65, total_pages 1, total_competitors 46 and total_events 15
# 2025-01-01 13:53:12,835 - INFO - Fetching page 1 for division 1
# 2025-01-01 13:53:12,836 - INFO - Starting API call for year 2012, division 1 and page 1
# 2025-01-01 13:53:12,935 - INFO - Successfully fetched data for year 2012, division 1 and page 1
# 2025-01-01 13:53:13,006 - INFO - Processing division 2
# 2025-01-01 13:53:13,006 - INFO - Fetching games info for year 2012 and division 2
# 2025-01-01 13:53:13,007 - INFO - Starting API call for year 2012, division 2 and page 1
# 2025-01-01 13:53:13,548 - INFO - Successfully fetched data for year 2012, division 2 and page 1
# 2025-01-01 13:53:13,551 - INFO - Fetched games metadata: competition_id 65, total_pages 1, total_competitors 45 and total_events 15
# 2025-01-01 13:53:13,552 - INFO - Fetching page 1 for division 2
# 2025-01-01 13:53:13,553 - INFO - Starting API call for year 2012, division 2 and page 1
# 2025-01-01 13:53:13,647 - INFO - Successfully fetched data for year 2012, division 2 and page 1
# 2025-01-01 13:53:13,717 - INFO - Fetched competitor info. Total competitors: 91
# 2025-01-01 13:53:13,721 - INFO - Fetching competitors info 2013 for division 0
# 2025-01-01 13:53:13,722 - INFO - Fetching competitor info for year 2013 and division 0
# 2025-01-01 13:53:13,725 - INFO - Processing division 1
# 2025-01-01 13:53:13,726 - INFO - Fetching games info for year 2013 and division 1
# 2025-01-01 13:53:13,726 - INFO - Starting API call for year 2013, division 1 and page 1
# 2025-01-01 13:53:14,261 - INFO - Successfully fetched data for year 2013, division 1 and page 1
# 2025-01-01 13:53:14,263 - INFO - Fetched games metadata: competition_id 16, total_pages 1, total_competitors 47 and total_events 12
# 2025-01-01 13:53:14,265 - INFO - Fetching page 1 for division 1
# 2025-01-01 13:53:14,265 - INFO - Starting API call for year 2013, division 1 and page 1
# 2025-01-01 13:53:14,363 - INFO - Successfully fetched data for year 2013, division 1 and page 1
# 2025-01-01 13:53:14,440 - INFO - Processing division 2
# 2025-01-01 13:53:14,441 - INFO - Fetching games info for year 2013 and division 2
# 2025-01-01 13:53:14,442 - INFO - Starting API call for year 2013, division 2 and page 1
# 2025-01-01 13:53:14,783 - INFO - Successfully fetched data for year 2013, division 2 and page 1
# 2025-01-01 13:53:14,785 - INFO - Fetched games metadata: competition_id 16, total_pages 1, total_competitors 44 and total_events 12
# 2025-01-01 13:53:14,786 - INFO - Fetching page 1 for division 2
# 2025-01-01 13:53:14,787 - INFO - Starting API call for year 2013, division 2 and page 1
# 2025-01-01 13:53:14,894 - INFO - Successfully fetched data for year 2013, division 2 and page 1
# 2025-01-01 13:53:14,962 - INFO - Fetched competitor info. Total competitors: 91
# 2025-01-01 13:53:14,964 - INFO - Fetching competitors info 2014 for division 0
# 2025-01-01 13:53:14,964 - INFO - Fetching competitor info for year 2014 and division 0
# 2025-01-01 13:53:14,965 - INFO - Processing division 1
# 2025-01-01 13:53:14,965 - INFO - Fetching games info for year 2014 and division 1
# 2025-01-01 13:53:14,966 - INFO - Starting API call for year 2014, division 1 and page 1
# 2025-01-01 13:53:15,366 - INFO - Successfully fetched data for year 2014, division 1 and page 1
# 2025-01-01 13:53:15,381 - INFO - Fetched games metadata: competition_id 15, total_pages 1, total_competitors 43 and total_events 13
# 2025-01-01 13:53:15,382 - INFO - Fetching page 1 for division 1
# 2025-01-01 13:53:15,383 - INFO - Starting API call for year 2014, division 1 and page 1
# 2025-01-01 13:53:15,734 - INFO - Successfully fetched data for year 2014, division 1 and page 1
# 2025-01-01 13:53:15,811 - INFO - Processing division 2
# 2025-01-01 13:53:15,813 - INFO - Fetching games info for year 2014 and division 2
# 2025-01-01 13:53:15,813 - INFO - Starting API call for year 2014, division 2 and page 1
# 2025-01-01 13:53:16,224 - INFO - Successfully fetched data for year 2014, division 2 and page 1
# 2025-01-01 13:53:16,226 - INFO - Fetched games metadata: competition_id 15, total_pages 1, total_competitors 43 and total_events 13
# 2025-01-01 13:53:16,227 - INFO - Fetching page 1 for division 2
# 2025-01-01 13:53:16,228 - INFO - Starting API call for year 2014, division 2 and page 1
# 2025-01-01 13:53:16,326 - INFO - Successfully fetched data for year 2014, division 2 and page 1
# 2025-01-01 13:53:16,388 - INFO - Fetched competitor info. Total competitors: 86
# 2025-01-01 13:53:16,390 - INFO - Fetching competitors info 2015 for division 0
# 2025-01-01 13:53:16,391 - INFO - Fetching competitor info for year 2015 and division 0
# 2025-01-01 13:53:16,391 - INFO - Processing division 1
# 2025-01-01 13:53:16,392 - INFO - Fetching games info for year 2015 and division 1
# 2025-01-01 13:53:16,392 - INFO - Starting API call for year 2015, division 1 and page 1
# 2025-01-01 13:53:16,824 - INFO - Successfully fetched data for year 2015, division 1 and page 1
# 2025-01-01 13:53:16,827 - INFO - Fetched games metadata: competition_id 14, total_pages 1, total_competitors 40 and total_events 13
# 2025-01-01 13:53:16,827 - INFO - Fetching page 1 for division 1
# 2025-01-01 13:53:16,828 - INFO - Starting API call for year 2015, division 1 and page 1
# 2025-01-01 13:53:16,922 - INFO - Successfully fetched data for year 2015, division 1 and page 1
# 2025-01-01 13:53:16,984 - INFO - Processing division 2
# 2025-01-01 13:53:16,984 - INFO - Fetching games info for year 2015 and division 2
# 2025-01-01 13:53:16,985 - INFO - Starting API call for year 2015, division 2 and page 1
# 2025-01-01 13:53:17,378 - INFO - Successfully fetched data for year 2015, division 2 and page 1
# 2025-01-01 13:53:17,380 - INFO - Fetched games metadata: competition_id 14, total_pages 1, total_competitors 40 and total_events 13
# 2025-01-01 13:53:17,381 - INFO - Fetching page 1 for division 2
# 2025-01-01 13:53:17,381 - INFO - Starting API call for year 2015, division 2 and page 1
# 2025-01-01 13:53:17,479 - INFO - Successfully fetched data for year 2015, division 2 and page 1
# 2025-01-01 13:53:17,538 - INFO - Fetched competitor info. Total competitors: 80
# 2025-01-01 13:53:17,541 - INFO - Fetching competitors info 2016 for division 0
# 2025-01-01 13:53:17,542 - INFO - Fetching competitor info for year 2016 and division 0
# 2025-01-01 13:53:17,542 - INFO - Processing division 1
# 2025-01-01 13:53:17,543 - INFO - Fetching games info for year 2016 and division 1
# 2025-01-01 13:53:17,543 - INFO - Starting API call for year 2016, division 1 and page 1
# 2025-01-01 13:53:18,053 - INFO - Successfully fetched data for year 2016, division 1 and page 1
# 2025-01-01 13:53:18,055 - INFO - Fetched games metadata: competition_id 13, total_pages 1, total_competitors 40 and total_events 15
# 2025-01-01 13:53:18,057 - INFO - Fetching page 1 for division 1
# 2025-01-01 13:53:18,057 - INFO - Starting API call for year 2016, division 1 and page 1
# 2025-01-01 13:53:18,152 - INFO - Successfully fetched data for year 2016, division 1 and page 1
# 2025-01-01 13:53:18,204 - INFO - Processing division 2
# 2025-01-01 13:53:18,204 - INFO - Fetching games info for year 2016 and division 2
# 2025-01-01 13:53:18,205 - INFO - Starting API call for year 2016, division 2 and page 1
# 2025-01-01 13:53:18,623 - INFO - Successfully fetched data for year 2016, division 2 and page 1
# 2025-01-01 13:53:18,627 - INFO - Fetched games metadata: competition_id 13, total_pages 1, total_competitors 40 and total_events 15
# 2025-01-01 13:53:18,628 - INFO - Fetching page 1 for division 2
# 2025-01-01 13:53:18,628 - INFO - Starting API call for year 2016, division 2 and page 1
# 2025-01-01 13:53:18,725 - INFO - Successfully fetched data for year 2016, division 2 and page 1
# 2025-01-01 13:53:18,813 - INFO - Fetched competitor info. Total competitors: 80
# 2025-01-01 13:53:18,818 - INFO - Fetching competitors info 2017 for division 0
# 2025-01-01 13:53:18,822 - INFO - Fetching competitor info for year 2017 and division 0
# 2025-01-01 13:53:18,823 - INFO - Processing division 1
# 2025-01-01 13:53:18,824 - INFO - Fetching games info for year 2017 and division 1
# 2025-01-01 13:53:18,826 - INFO - Starting API call for year 2017, division 1 and page 1
# 2025-01-01 13:53:19,216 - INFO - Successfully fetched data for year 2017, division 1 and page 1
# 2025-01-01 13:53:19,249 - INFO - Fetched games metadata: competition_id 3, total_pages 1, total_competitors 39 and total_events 13
# 2025-01-01 13:53:19,262 - INFO - Fetching page 1 for division 1
# 2025-01-01 13:53:19,264 - INFO - Starting API call for year 2017, division 1 and page 1
# 2025-01-01 13:53:19,362 - INFO - Successfully fetched data for year 2017, division 1 and page 1
# 2025-01-01 13:53:19,466 - INFO - Processing division 2
# 2025-01-01 13:53:19,469 - INFO - Fetching games info for year 2017 and division 2
# 2025-01-01 13:53:19,470 - INFO - Starting API call for year 2017, division 2 and page 1
# 2025-01-01 13:53:19,920 - INFO - Successfully fetched data for year 2017, division 2 and page 1
# 2025-01-01 13:53:19,925 - INFO - Fetched games metadata: competition_id 3, total_pages 1, total_competitors 40 and total_events 13
# 2025-01-01 13:53:19,929 - INFO - Fetching page 1 for division 2
# 2025-01-01 13:53:19,931 - INFO - Starting API call for year 2017, division 2 and page 1
# 2025-01-01 13:53:20,030 - INFO - Successfully fetched data for year 2017, division 2 and page 1
# 2025-01-01 13:53:20,125 - INFO - Fetched competitor info. Total competitors: 79
# 2025-01-01 13:53:20,128 - INFO - Fetching competitors info 2018 for division 0
# 2025-01-01 13:53:20,129 - INFO - Fetching competitor info for year 2018 and division 0
# 2025-01-01 13:53:20,130 - INFO - Processing division 1
# 2025-01-01 13:53:20,130 - INFO - Fetching games info for year 2018 and division 1
# 2025-01-01 13:53:20,131 - INFO - Starting API call for year 2018, division 1 and page 1
# 2025-01-01 13:53:20,236 - INFO - Successfully fetched data for year 2018, division 1 and page 1
# 2025-01-01 13:53:20,238 - INFO - Fetched games metadata: competition_id 31, total_pages 1, total_competitors 40 and total_events 14
# 2025-01-01 13:53:20,239 - INFO - Fetching page 1 for division 1
# 2025-01-01 13:53:20,240 - INFO - Starting API call for year 2018, division 1 and page 1
# 2025-01-01 13:53:20,338 - INFO - Successfully fetched data for year 2018, division 1 and page 1
# 2025-01-01 13:53:20,436 - INFO - Processing division 2
# 2025-01-01 13:53:20,440 - INFO - Fetching games info for year 2018 and division 2
# 2025-01-01 13:53:20,442 - INFO - Starting API call for year 2018, division 2 and page 1
# 2025-01-01 13:53:20,856 - INFO - Successfully fetched data for year 2018, division 2 and page 1
# 2025-01-01 13:53:20,859 - INFO - Fetched games metadata: competition_id 31, total_pages 1, total_competitors 40 and total_events 14
# 2025-01-01 13:53:20,860 - INFO - Fetching page 1 for division 2
# 2025-01-01 13:53:20,861 - INFO - Starting API call for year 2018, division 2 and page 1
# 2025-01-01 13:53:20,961 - INFO - Successfully fetched data for year 2018, division 2 and page 1
# 2025-01-01 13:53:21,049 - INFO - Fetched competitor info. Total competitors: 80
# 2025-01-01 13:53:21,054 - INFO - Fetching competitors info 2019 for division 0
# 2025-01-01 13:53:21,054 - INFO - Fetching competitor info for year 2019 and division 0
# 2025-01-01 13:53:21,056 - INFO - Processing division 1
# 2025-01-01 13:53:21,057 - INFO - Fetching games info for year 2019 and division 1
# 2025-01-01 13:53:21,057 - INFO - Starting API call for year 2019, division 1 and page 1
# 2025-01-01 13:53:21,156 - INFO - Successfully fetched data for year 2019, division 1 and page 1
# 2025-01-01 13:53:21,160 - INFO - Fetched games metadata: competition_id 52, total_pages 3, total_competitors 144 and total_events 12
# 2025-01-01 13:53:21,161 - INFO - Fetching page 1 for division 1
# 2025-01-01 13:53:21,162 - INFO - Starting API call for year 2019, division 1 and page 1
# 2025-01-01 13:53:21,295 - INFO - Successfully fetched data for year 2019, division 1 and page 1
# 2025-01-01 13:53:21,394 - INFO - Fetching page 2 for division 1
# 2025-01-01 13:53:21,395 - INFO - Starting API call for year 2019, division 1 and page 2
# 2025-01-01 13:53:21,815 - INFO - Successfully fetched data for year 2019, division 1 and page 2
# 2025-01-01 13:53:21,915 - INFO - Fetching page 3 for division 1
# 2025-01-01 13:53:21,916 - INFO - Starting API call for year 2019, division 1 and page 3
# 2025-01-01 13:53:22,326 - INFO - Successfully fetched data for year 2019, division 1 and page 3
# 2025-01-01 13:53:22,465 - INFO - Processing division 2
# 2025-01-01 13:53:22,467 - INFO - Fetching games info for year 2019 and division 2
# 2025-01-01 13:53:22,468 - INFO - Starting API call for year 2019, division 2 and page 1
# 2025-01-01 13:53:22,870 - INFO - Successfully fetched data for year 2019, division 2 and page 1
# 2025-01-01 13:53:22,873 - INFO - Fetched games metadata: competition_id 52, total_pages 3, total_competitors 131 and total_events 12
# 2025-01-01 13:53:22,874 - INFO - Fetching page 1 for division 2
# 2025-01-01 13:53:22,875 - INFO - Starting API call for year 2019, division 2 and page 1
# 2025-01-01 13:53:22,996 - INFO - Successfully fetched data for year 2019, division 2 and page 1
# 2025-01-01 13:53:23,140 - INFO - Fetching page 2 for division 2
# 2025-01-01 13:53:23,141 - INFO - Starting API call for year 2019, division 2 and page 2
# 2025-01-01 13:53:23,544 - INFO - Successfully fetched data for year 2019, division 2 and page 2
# 2025-01-01 13:53:23,663 - INFO - Fetching page 3 for division 2
# 2025-01-01 13:53:23,665 - INFO - Starting API call for year 2019, division 2 and page 3
# 2025-01-01 13:53:23,969 - INFO - Successfully fetched data for year 2019, division 2 and page 3
# 2025-01-01 13:53:24,025 - INFO - Fetched competitor info. Total competitors: 275
# 2025-01-01 13:53:24,028 - INFO - Fetching competitors info 2020 for division 0
# 2025-01-01 13:53:24,029 - INFO - Fetching competitor info for year 2020 and division 0
# 2025-01-01 13:53:24,030 - INFO - Processing division 1
# 2025-01-01 13:53:24,031 - INFO - Fetching games info for year 2020 and division 1
# 2025-01-01 13:53:24,032 - INFO - Starting API call for year 2020, division 1 and page 1
# 2025-01-01 13:53:24,127 - INFO - Successfully fetched data for year 2020, division 1 and page 1
# 2025-01-01 13:53:24,130 - INFO - Fetched games metadata: competition_id 58, total_pages 1, total_competitors 30 and total_events 20
# 2025-01-01 13:53:24,131 - INFO - Fetching page 1 for division 1
# 2025-01-01 13:53:24,131 - INFO - Starting API call for year 2020, division 1 and page 1
# 2025-01-01 13:53:24,264 - INFO - Successfully fetched data for year 2020, division 1 and page 1
# 2025-01-01 13:53:24,303 - INFO - Processing division 2
# 2025-01-01 13:53:24,304 - INFO - Fetching games info for year 2020 and division 2
# 2025-01-01 13:53:24,304 - INFO - Starting API call for year 2020, division 2 and page 1
# 2025-01-01 13:53:24,817 - INFO - Successfully fetched data for year 2020, division 2 and page 1
# 2025-01-01 13:53:24,820 - INFO - Fetched games metadata: competition_id 58, total_pages 1, total_competitors 30 and total_events 20
# 2025-01-01 13:53:24,820 - INFO - Fetching page 1 for division 2
# 2025-01-01 13:53:24,821 - INFO - Starting API call for year 2020, division 2 and page 1
# 2025-01-01 13:53:24,915 - INFO - Successfully fetched data for year 2020, division 2 and page 1
# 2025-01-01 13:53:24,992 - INFO - Fetched competitor info. Total competitors: 60
# 2025-01-01 13:53:24,997 - INFO - Fetching competitors info 2021 for division 0
# 2025-01-01 13:53:24,998 - INFO - Fetching competitor info for year 2021 and division 0
# 2025-01-01 13:53:24,998 - INFO - Processing division 1
# 2025-01-01 13:53:24,999 - INFO - Fetching games info for year 2021 and division 1
# 2025-01-01 13:53:24,999 - INFO - Starting API call for year 2021, division 1 and page 1
# 2025-01-01 13:53:25,097 - INFO - Successfully fetched data for year 2021, division 1 and page 1
# 2025-01-01 13:53:25,100 - INFO - Fetched games metadata: competition_id 161, total_pages 1, total_competitors 40 and total_events 15
# 2025-01-01 13:53:25,101 - INFO - Fetching page 1 for division 1
# 2025-01-01 13:53:25,101 - INFO - Starting API call for year 2021, division 1 and page 1
# 2025-01-01 13:53:25,194 - INFO - Successfully fetched data for year 2021, division 1 and page 1
# 2025-01-01 13:53:25,245 - INFO - Processing division 2
# 2025-01-01 13:53:25,246 - INFO - Fetching games info for year 2021 and division 2
# 2025-01-01 13:53:25,246 - INFO - Starting API call for year 2021, division 2 and page 1
# 2025-01-01 13:53:25,737 - INFO - Successfully fetched data for year 2021, division 2 and page 1
# 2025-01-01 13:53:25,741 - INFO - Fetched games metadata: competition_id 161, total_pages 1, total_competitors 40 and total_events 15
# 2025-01-01 13:53:25,742 - INFO - Fetching page 1 for division 2
# 2025-01-01 13:53:25,743 - INFO - Starting API call for year 2021, division 2 and page 1
# 2025-01-01 13:53:25,838 - INFO - Successfully fetched data for year 2021, division 2 and page 1
# 2025-01-01 13:53:25,902 - INFO - Fetched competitor info. Total competitors: 80
# 2025-01-01 13:53:25,907 - INFO - Fetching competitors info 2022 for division 0
# 2025-01-01 13:53:25,907 - INFO - Fetching competitor info for year 2022 and division 0
# 2025-01-01 13:53:25,908 - INFO - Processing division 1
# 2025-01-01 13:53:25,909 - INFO - Fetching games info for year 2022 and division 1
# 2025-01-01 13:53:25,909 - INFO - Starting API call for year 2022, division 1 and page 1
# 2025-01-01 13:53:26,008 - INFO - Successfully fetched data for year 2022, division 1 and page 1
# 2025-01-01 13:53:26,012 - INFO - Fetched games metadata: competition_id 189, total_pages 1, total_competitors 40 and total_events 14
# 2025-01-01 13:53:26,013 - INFO - Fetching page 1 for division 1
# 2025-01-01 13:53:26,013 - INFO - Starting API call for year 2022, division 1 and page 1
# 2025-01-01 13:53:26,109 - INFO - Successfully fetched data for year 2022, division 1 and page 1
# 2025-01-01 13:53:26,165 - INFO - Processing division 2
# 2025-01-01 13:53:26,166 - INFO - Fetching games info for year 2022 and division 2
# 2025-01-01 13:53:26,167 - INFO - Starting API call for year 2022, division 2 and page 1
# 2025-01-01 13:53:26,652 - INFO - Successfully fetched data for year 2022, division 2 and page 1
# 2025-01-01 13:53:26,655 - INFO - Fetched games metadata: competition_id 189, total_pages 1, total_competitors 40 and total_events 14
# 2025-01-01 13:53:26,656 - INFO - Fetching page 1 for division 2
# 2025-01-01 13:53:26,657 - INFO - Starting API call for year 2022, division 2 and page 1
# 2025-01-01 13:53:26,753 - INFO - Successfully fetched data for year 2022, division 2 and page 1
# 2025-01-01 13:53:26,810 - INFO - Fetched competitor info. Total competitors: 80
# 2025-01-01 13:53:26,813 - INFO - Fetching competitors info 2023 for division 0
# 2025-01-01 13:53:26,813 - INFO - Fetching competitor info for year 2023 and division 0
# 2025-01-01 13:53:26,814 - INFO - Processing division 1
# 2025-01-01 13:53:26,815 - INFO - Fetching games info for year 2023 and division 1
# 2025-01-01 13:53:26,815 - INFO - Starting API call for year 2023, division 1 and page 1
# 2025-01-01 13:53:27,215 - INFO - Successfully fetched data for year 2023, division 1 and page 1
# 2025-01-01 13:53:27,217 - INFO - Fetched games metadata: competition_id 223, total_pages 1, total_competitors 40 and total_events 12
# 2025-01-01 13:53:27,218 - INFO - Fetching page 1 for division 1
# 2025-01-01 13:53:27,219 - INFO - Starting API call for year 2023, division 1 and page 1
# 2025-01-01 13:53:27,312 - INFO - Successfully fetched data for year 2023, division 1 and page 1
# 2025-01-01 13:53:27,364 - INFO - Processing division 2
# 2025-01-01 13:53:27,364 - INFO - Fetching games info for year 2023 and division 2
# 2025-01-01 13:53:27,365 - INFO - Starting API call for year 2023, division 2 and page 1
# 2025-01-01 13:53:27,783 - INFO - Successfully fetched data for year 2023, division 2 and page 1
# 2025-01-01 13:53:27,786 - INFO - Fetched games metadata: competition_id 223, total_pages 1, total_competitors 40 and total_events 12
# 2025-01-01 13:53:27,787 - INFO - Fetching page 1 for division 2
# 2025-01-01 13:53:27,788 - INFO - Starting API call for year 2023, division 2 and page 1
# 2025-01-01 13:53:27,884 - INFO - Successfully fetched data for year 2023, division 2 and page 1
# 2025-01-01 13:53:27,939 - INFO - Fetched competitor info. Total competitors: 80
# 2025-01-01 13:53:27,941 - INFO - Fetching competitors info 2024 for division 0
# 2025-01-01 13:53:27,942 - INFO - Fetching competitor info for year 2024 and division 0
# 2025-01-01 13:53:27,943 - INFO - Processing division 1
# 2025-01-01 13:53:27,943 - INFO - Fetching games info for year 2024 and division 1
# 2025-01-01 13:53:27,944 - INFO - Starting API call for year 2024, division 1 and page 1
# 2025-01-01 13:53:28,394 - INFO - Successfully fetched data for year 2024, division 1 and page 1
# 2025-01-01 13:53:28,397 - INFO - Fetched games metadata: competition_id 225, total_pages 1, total_competitors 39 and total_events 10
# 2025-01-01 13:53:28,397 - INFO - Fetching page 1 for division 1
# 2025-01-01 13:53:28,398 - INFO - Starting API call for year 2024, division 1 and page 1
# 2025-01-01 13:53:28,494 - INFO - Successfully fetched data for year 2024, division 1 and page 1
# 2025-01-01 13:53:28,543 - INFO - Processing division 2
# 2025-01-01 13:53:28,544 - INFO - Fetching games info for year 2024 and division 2
# 2025-01-01 13:53:28,544 - INFO - Starting API call for year 2024, division 2 and page 1
# 2025-01-01 13:53:28,861 - INFO - Successfully fetched data for year 2024, division 2 and page 1
# 2025-01-01 13:53:28,864 - INFO - Fetched games metadata: competition_id 225, total_pages 1, total_competitors 40 and total_events 10
# 2025-01-01 13:53:28,874 - INFO - Fetching page 1 for division 2
# 2025-01-01 13:53:28,876 - INFO - Starting API call for year 2024, division 2 and page 1
# 2025-01-01 13:53:28,973 - INFO - Successfully fetched data for year 2024, division 2 and page 1
# 2025-01-01 13:53:29,037 - INFO - Fetched competitor info. Total competitors: 79

# %%
competitors = pd.read_csv(f'../data/{file_name}.csv')
competitors.head(5)
# Out:
#    Unnamed: 0  competitorId    competitorName firstName    lastName status  \
# 0           0        164070  James Fitzgerald     James  Fitzgerald    ACT
# 1           1         57785    Brett Marshall     Brett    Marshall    ACT
# 2           2         10091      Josh Everett      Josh     Everett    ACT
# 3           3         27065    Chris Spealler     Chris    Spealler    ACT
# 4           4          7173       Breck Berry     Breck       Berry    ACT
#
#    postCompStatus gender          profilePicS3key countryOfOriginCode  ...  \
# 0             NaN      M  0a1aa-P164070_2-184.jpg                 NaN  ...
# 1             NaN      M   e11d1-P57785_2-184.jpg                 NaN  ...
# 2             NaN      M   98160-P10091_2-184.jpg                 NaN  ...
# 3             NaN      M   28faf-P27065_3-184.jpg                 NaN  ...
# 4             NaN      M    f142a-P7173_6-184.jpg                 NaN  ...
#
#   affiliateName  age  height  weight  teamCaptain  overallScore overallRank  \
# 0           NaN   33   69 in  176 lb            0           272           1
# 1           NaN   33  168 cm  155 lb            0           270           2
# 2           NaN   32   69 in  185 lb            0           267           3
# 3           NaN   28   65 in  143 lb            0           261           4
# 4           NaN   31   67 in  170 lb            0           252           5
#
#    heightInCm weightInKg  year
# 0       175.3       79.8  2007
# 1       168.0       70.3  2007
# 2       175.3       83.9  2007
# 3       165.1       64.9  2007
# 4       170.2       77.1  2007
#
# [5 rows x 26 columns]

# %%
competitors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1792 entries, 0 to 1791
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           1792 non-null   int64
#  1   competitorId         1792 non-null   int64
#  2   competitorName       1792 non-null   object
#  3   firstName            1792 non-null   object
#  4   lastName             1791 non-null   object
#  5   status               1792 non-null   object
#  6   postCompStatus       0 non-null      float64
#  7   gender               1792 non-null   object
#  8   profilePicS3key      1792 non-null   object
#  9   countryOfOriginCode  1068 non-null   object
#  10  countryOfOriginName  1054 non-null   object
#  11  countryShortCode     0 non-null      float64
#  12  regionId             906 non-null    float64
#  13  regionName           906 non-null    object
#  14  divisionId           1792 non-null   int64
#  15  affiliateId          972 non-null    float64
#  16  affiliateName        972 non-null    object
#  17  age                  1792 non-null   int64
#  18  height               1623 non-null   object
#  19  weight               1628 non-null   object
#  20  teamCaptain          1792 non-null   int64
#  21  overallScore         1792 non-null   object
#  22  overallRank          1792 non-null   int64
#  23  heightInCm           1623 non-null   float64
#  24  weightInKg           1628 non-null   float64
#  25  year                 1792 non-null   int64
# dtypes: float64(6), int64(7), object(13)
# memory usage: 364.1+ KB

# %%
competitors[competitors['competitorName'] == 'Björgvin Karl Guðmundsson']
# Out:
#       Unnamed: 0  competitorId             competitorName      firstName  \
# 758          758         81616  Björgvin Karl Guðmundsson  Björgvin Karl
# 821          821         81616  Björgvin Karl Guðmundsson  Björgvin Karl
# 906          906         81616  Björgvin Karl Guðmundsson  Björgvin Karl
# 984          984         81616  Björgvin Karl Guðmundsson  Björgvin Karl
# 1062        1062         81616  Björgvin Karl Guðmundsson  Björgvin Karl
# 1140        1140         81616  Björgvin Karl Guðmundsson  Björgvin Karl
# 1420        1420         81616  Björgvin Karl Guðmundsson  Björgvin Karl
# 1476        1476         81616  Björgvin Karl Guðmundsson  Björgvin Karl
# 1561        1561         81616  Björgvin Karl Guðmundsson  Björgvin Karl
# 1643        1643         81616  Björgvin Karl Guðmundsson  Björgvin Karl
# 1728        1728         81616  Björgvin Karl Guðmundsson  Björgvin Karl
#
#          lastName status  postCompStatus gender         profilePicS3key  \
# 758   Guðmundsson    ACT             NaN      M  4c5dc-P81616_4-184.jpg
# 821   Guðmundsson    ACT             NaN      M  4c5dc-P81616_4-184.jpg
# 906   Guðmundsson    ACT             NaN      M  4c5dc-P81616_4-184.jpg
# 984   Guðmundsson    ACT             NaN      M  4c5dc-P81616_4-184.jpg
# 1062  Guðmundsson    ACT             NaN      M  4c5dc-P81616_4-184.jpg
# 1140  Guðmundsson    ACT             NaN      M  4c5dc-P81616_4-184.jpg
# 1420  Guðmundsson    ACT             NaN      M  4c5dc-P81616_4-184.jpg
# 1476  Guðmundsson    ACT             NaN      M  4c5dc-P81616_4-184.jpg
# 1561  Guðmundsson    ACT             NaN      M  4c5dc-P81616_4-184.jpg
# 1643  Guðmundsson    ACT             NaN      M  4c5dc-P81616_4-184.jpg
# 1728  Guðmundsson    ACT             NaN      M  4c5dc-P81616_4-184.jpg
#
#      countryOfOriginCode  ...       affiliateName  age  height  weight  \
# 758                  NaN  ...    CrossFit Hengill   21  178 cm  190 lb
# 821                   IS  ...    CrossFit Hengill   22  178 cm  190 lb
# 906                   IS  ...    CrossFit Hengill   23  178 cm  190 lb
# 984                   IS  ...                 NaN   24  178 cm  190 lb
# 1062                  IS  ...    CrossFit Hengill   25  178 cm  190 lb
# 1140                  IS  ...    CrossFit Hengill   26  178 cm  190 lb
# 1420                  IS  ...    CrossFit Hengill   27  178 cm  190 lb
# 1476                  IS  ...    CrossFit Hengill   28  178 cm  190 lb
# 1561                  IS  ...    CrossFit Hengill   29  178 cm  190 lb
# 1643                  IS  ...    CrossFit Hengill   30  178 cm  190 lb
# 1728                  IS  ...  CrossFit Reykjavík   31  178 cm  190 lb
#
#       teamCaptain  overallScore overallRank  heightInCm weightInKg  year
# 758             0           517          26       178.0       86.2  2014
# 821             0           766           3       178.0       86.2  2015
# 906             0           735           8       178.0       86.2  2016
# 984             0           786           5       178.0       86.2  2017
# 1062            0           834           5       178.0       86.2  2018
# 1140            0           888           3       178.0       86.2  2019
# 1420            0             0           8       178.0       86.2  2020
# 1476            0          1004           4       178.0       86.2  2021
# 1561            0           841           9       178.0       86.2  2022
# 1643            0           710          11       178.0       86.2  2023
# 1728            0           524          16       178.0       86.2  2024
#
# [11 rows x 26 columns]

# %% [markdown]
# ### Calling the api for info on multiple games and their events and writing the results to a csv

# %%
timestr = time.strftime("%Y%m%d_%H%M%S")
df_games_info_scores_multiple = games_info_scores_multiple(2007, 2024,0)
file_name = f'games_info_scores_multiple_{timestr}'
df_games_info_scores_multiple.to_csv(f'../data/{file_name}.csv')
# Out:
# 2025-01-01 13:54:56,849 - INFO - Fetching games info score for year 2007
# 2025-01-01 13:54:56,850 - INFO - Processing division 1 for year 2007.
# 2025-01-01 13:54:56,851 - INFO - Fetching games info for year 2007 and division 1
# 2025-01-01 13:54:56,852 - INFO - Starting API call for year 2007, division 1 and page 1
# 2025-01-01 13:54:57,002 - INFO - Successfully fetched data for year 2007, division 1 and page 1
# 2025-01-01 13:54:57,004 - INFO - Fetched games metadata: competition_id 59, total_pages 1, total_competitors 44 and total_events 3
# 2025-01-01 13:54:57,005 - INFO - Total pages: 1, Total results: 44.
# 2025-01-01 13:54:57,005 - INFO - Fetching data for page 1.
# 2025-01-01 13:54:57,006 - INFO - Starting API call for year 2007, division 1 and page 1
# 2025-01-01 13:54:57,098 - INFO - Successfully fetched data for year 2007, division 1 and page 1
# 2025-01-01 13:54:57,161 - INFO - Processing division 2 for year 2007.
# 2025-01-01 13:54:57,161 - INFO - Fetching games info for year 2007 and division 2
# 2025-01-01 13:54:57,161 - INFO - Starting API call for year 2007, division 2 and page 1
# 2025-01-01 13:54:57,254 - INFO - Successfully fetched data for year 2007, division 2 and page 1
# 2025-01-01 13:54:57,255 - INFO - Fetched games metadata: competition_id 59, total_pages 1, total_competitors 20 and total_events 3
# 2025-01-01 13:54:57,257 - INFO - Total pages: 1, Total results: 20.
# 2025-01-01 13:54:57,257 - INFO - Fetching data for page 1.
# 2025-01-01 13:54:57,258 - INFO - Starting API call for year 2007, division 2 and page 1
# 2025-01-01 13:54:57,350 - INFO - Successfully fetched data for year 2007, division 2 and page 1
# 2025-01-01 13:54:57,382 - INFO - Transforming rank and other columns.
# 2025-01-01 13:54:57,391 - INFO - Dataframe transformation complete. Returning dataframe.
# 2025-01-01 13:54:57,393 - INFO - Fetching games info score for year 2008
# 2025-01-01 13:54:57,394 - INFO - Processing division 1 for year 2008.
# 2025-01-01 13:54:57,395 - INFO - Fetching games info for year 2008 and division 1
# 2025-01-01 13:54:57,395 - INFO - Starting API call for year 2008, division 1 and page 1
# 2025-01-01 13:54:57,486 - INFO - Successfully fetched data for year 2008, division 1 and page 1
# 2025-01-01 13:54:57,488 - INFO - Fetched games metadata: competition_id 60, total_pages 3, total_competitors 119 and total_events 4
# 2025-01-01 13:54:57,488 - INFO - Total pages: 3, Total results: 119.
# 2025-01-01 13:54:57,489 - INFO - Fetching data for page 1.
# 2025-01-01 13:54:57,489 - INFO - Starting API call for year 2008, division 1 and page 1
# 2025-01-01 13:54:57,581 - INFO - Successfully fetched data for year 2008, division 1 and page 1
# 2025-01-01 13:54:57,672 - INFO - Fetching data for page 2.
# 2025-01-01 13:54:57,673 - INFO - Starting API call for year 2008, division 1 and page 2
# 2025-01-01 13:54:57,765 - INFO - Successfully fetched data for year 2008, division 1 and page 2
# 2025-01-01 13:54:57,852 - INFO - Fetching data for page 3.
# 2025-01-01 13:54:57,853 - INFO - Starting API call for year 2008, division 1 and page 3
# 2025-01-01 13:54:57,946 - INFO - Successfully fetched data for year 2008, division 1 and page 3
# 2025-01-01 13:54:57,973 - INFO - Processing division 2 for year 2008.
# 2025-01-01 13:54:57,974 - INFO - Fetching games info for year 2008 and division 2
# 2025-01-01 13:54:57,974 - INFO - Starting API call for year 2008, division 2 and page 1
# 2025-01-01 13:54:58,066 - INFO - Successfully fetched data for year 2008, division 2 and page 1
# 2025-01-01 13:54:58,067 - INFO - Fetched games metadata: competition_id 60, total_pages 1, total_competitors 36 and total_events 4
# 2025-01-01 13:54:58,068 - INFO - Total pages: 1, Total results: 36.
# 2025-01-01 13:54:58,069 - INFO - Fetching data for page 1.
# 2025-01-01 13:54:58,069 - INFO - Starting API call for year 2008, division 2 and page 1
# 2025-01-01 13:54:58,168 - INFO - Successfully fetched data for year 2008, division 2 and page 1
# 2025-01-01 13:54:58,221 - INFO - Transforming rank and other columns.
# 2025-01-01 13:54:58,233 - INFO - Dataframe transformation complete. Returning dataframe.
# /Users/lindalarusdottir/Arnar/Projects/CrossfitGames/src/crossfitgames/api/api_calls.py:281: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_games_info_scores_multiple = pd.concat([df_games_info_scores_multiple, df_temp], ignore_index=True)
# 2025-01-01 13:54:58,237 - INFO - Fetching games info score for year 2009
# 2025-01-01 13:54:58,238 - INFO - Processing division 1 for year 2009.
# 2025-01-01 13:54:58,238 - INFO - Fetching games info for year 2009 and division 1
# 2025-01-01 13:54:58,239 - INFO - Starting API call for year 2009, division 1 and page 1
# 2025-01-01 13:54:58,334 - INFO - Successfully fetched data for year 2009, division 1 and page 1
# 2025-01-01 13:54:58,336 - INFO - Fetched games metadata: competition_id 61, total_pages 2, total_competitors 74 and total_events 8
# 2025-01-01 13:54:58,337 - INFO - Total pages: 2, Total results: 74.
# 2025-01-01 13:54:58,337 - INFO - Fetching data for page 1.
# 2025-01-01 13:54:58,337 - INFO - Starting API call for year 2009, division 1 and page 1
# 2025-01-01 13:54:58,431 - INFO - Successfully fetched data for year 2009, division 1 and page 1
# 2025-01-01 13:54:58,502 - INFO - Fetching data for page 2.
# 2025-01-01 13:54:58,502 - INFO - Starting API call for year 2009, division 1 and page 2
# 2025-01-01 13:54:58,593 - INFO - Successfully fetched data for year 2009, division 1 and page 2
# 2025-01-01 13:54:58,634 - INFO - Processing division 2 for year 2009.
# 2025-01-01 13:54:58,634 - INFO - Fetching games info for year 2009 and division 2
# 2025-01-01 13:54:58,635 - INFO - Starting API call for year 2009, division 2 and page 1
# 2025-01-01 13:54:58,734 - INFO - Successfully fetched data for year 2009, division 2 and page 1
# 2025-01-01 13:54:58,736 - INFO - Fetched games metadata: competition_id 61, total_pages 2, total_competitors 72 and total_events 8
# 2025-01-01 13:54:58,737 - INFO - Total pages: 2, Total results: 72.
# 2025-01-01 13:54:58,737 - INFO - Fetching data for page 1.
# 2025-01-01 13:54:58,738 - INFO - Starting API call for year 2009, division 2 and page 1
# 2025-01-01 13:54:58,835 - INFO - Successfully fetched data for year 2009, division 2 and page 1
# 2025-01-01 13:54:58,907 - INFO - Fetching data for page 2.
# 2025-01-01 13:54:58,907 - INFO - Starting API call for year 2009, division 2 and page 2
# 2025-01-01 13:54:59,001 - INFO - Successfully fetched data for year 2009, division 2 and page 2
# 2025-01-01 13:54:59,038 - INFO - Transforming rank and other columns.
# 2025-01-01 13:54:59,052 - INFO - Dataframe transformation complete. Returning dataframe.
# 2025-01-01 13:54:59,055 - INFO - Fetching games info score for year 2010
# 2025-01-01 13:54:59,056 - INFO - Processing division 1 for year 2010.
# 2025-01-01 13:54:59,057 - INFO - Fetching games info for year 2010 and division 1
# 2025-01-01 13:54:59,057 - INFO - Starting API call for year 2010, division 1 and page 1
# 2025-01-01 13:54:59,160 - INFO - Successfully fetched data for year 2010, division 1 and page 1
# 2025-01-01 13:54:59,162 - INFO - Fetched games metadata: competition_id 62, total_pages 1, total_competitors 45 and total_events 9
# 2025-01-01 13:54:59,163 - INFO - Total pages: 1, Total results: 45.
# 2025-01-01 13:54:59,164 - INFO - Fetching data for page 1.
# 2025-01-01 13:54:59,165 - INFO - Starting API call for year 2010, division 1 and page 1
# 2025-01-01 13:54:59,257 - INFO - Successfully fetched data for year 2010, division 1 and page 1
# 2025-01-01 13:54:59,334 - INFO - Processing division 2 for year 2010.
# 2025-01-01 13:54:59,334 - INFO - Fetching games info for year 2010 and division 2
# 2025-01-01 13:54:59,335 - INFO - Starting API call for year 2010, division 2 and page 1
# 2025-01-01 13:54:59,427 - INFO - Successfully fetched data for year 2010, division 2 and page 1
# 2025-01-01 13:54:59,429 - INFO - Fetched games metadata: competition_id 62, total_pages 1, total_competitors 45 and total_events 9
# 2025-01-01 13:54:59,430 - INFO - Total pages: 1, Total results: 45.
# 2025-01-01 13:54:59,430 - INFO - Fetching data for page 1.
# 2025-01-01 13:54:59,431 - INFO - Starting API call for year 2010, division 2 and page 1
# 2025-01-01 13:54:59,523 - INFO - Successfully fetched data for year 2010, division 2 and page 1
# 2025-01-01 13:54:59,595 - INFO - Transforming rank and other columns.
# 2025-01-01 13:54:59,604 - INFO - Dataframe transformation complete. Returning dataframe.
# 2025-01-01 13:54:59,607 - INFO - Fetching games info score for year 2011
# 2025-01-01 13:54:59,608 - INFO - Processing division 1 for year 2011.
# 2025-01-01 13:54:59,608 - INFO - Fetching games info for year 2011 and division 1
# 2025-01-01 13:54:59,609 - INFO - Starting API call for year 2011, division 1 and page 1
# 2025-01-01 13:54:59,702 - INFO - Successfully fetched data for year 2011, division 1 and page 1
# 2025-01-01 13:54:59,705 - INFO - Fetched games metadata: competition_id 63, total_pages 1, total_competitors 49 and total_events 10
# 2025-01-01 13:54:59,705 - INFO - Total pages: 1, Total results: 49.
# 2025-01-01 13:54:59,706 - INFO - Fetching data for page 1.
# 2025-01-01 13:54:59,706 - INFO - Starting API call for year 2011, division 1 and page 1
# 2025-01-01 13:54:59,799 - INFO - Successfully fetched data for year 2011, division 1 and page 1
# 2025-01-01 13:54:59,870 - INFO - Processing division 2 for year 2011.
# 2025-01-01 13:54:59,871 - INFO - Fetching games info for year 2011 and division 2
# 2025-01-01 13:54:59,871 - INFO - Starting API call for year 2011, division 2 and page 1
# 2025-01-01 13:54:59,965 - INFO - Successfully fetched data for year 2011, division 2 and page 1
# 2025-01-01 13:54:59,968 - INFO - Fetched games metadata: competition_id 63, total_pages 1, total_competitors 47 and total_events 10
# 2025-01-01 13:54:59,969 - INFO - Total pages: 1, Total results: 47.
# 2025-01-01 13:54:59,969 - INFO - Fetching data for page 1.
# 2025-01-01 13:54:59,970 - INFO - Starting API call for year 2011, division 2 and page 1
# 2025-01-01 13:55:00,063 - INFO - Successfully fetched data for year 2011, division 2 and page 1
# 2025-01-01 13:55:00,133 - INFO - Transforming rank and other columns.
# 2025-01-01 13:55:00,143 - INFO - Dataframe transformation complete. Returning dataframe.
# /Users/lindalarusdottir/Arnar/Projects/CrossfitGames/src/crossfitgames/api/api_calls.py:281: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_games_info_scores_multiple = pd.concat([df_games_info_scores_multiple, df_temp], ignore_index=True)
# 2025-01-01 13:55:00,147 - INFO - Fetching games info score for year 2012
# 2025-01-01 13:55:00,147 - INFO - Processing division 1 for year 2012.
# 2025-01-01 13:55:00,148 - INFO - Fetching games info for year 2012 and division 1
# 2025-01-01 13:55:00,149 - INFO - Starting API call for year 2012, division 1 and page 1
# 2025-01-01 13:55:00,244 - INFO - Successfully fetched data for year 2012, division 1 and page 1
# 2025-01-01 13:55:00,248 - INFO - Fetched games metadata: competition_id 65, total_pages 1, total_competitors 46 and total_events 15
# 2025-01-01 13:55:00,248 - INFO - Total pages: 1, Total results: 46.
# 2025-01-01 13:55:00,249 - INFO - Fetching data for page 1.
# 2025-01-01 13:55:00,249 - INFO - Starting API call for year 2012, division 1 and page 1
# 2025-01-01 13:55:00,345 - INFO - Successfully fetched data for year 2012, division 1 and page 1
# 2025-01-01 13:55:00,414 - INFO - Processing division 2 for year 2012.
# 2025-01-01 13:55:00,415 - INFO - Fetching games info for year 2012 and division 2
# 2025-01-01 13:55:00,415 - INFO - Starting API call for year 2012, division 2 and page 1
# 2025-01-01 13:55:00,516 - INFO - Successfully fetched data for year 2012, division 2 and page 1
# 2025-01-01 13:55:00,519 - INFO - Fetched games metadata: competition_id 65, total_pages 1, total_competitors 45 and total_events 15
# 2025-01-01 13:55:00,520 - INFO - Total pages: 1, Total results: 45.
# 2025-01-01 13:55:00,520 - INFO - Fetching data for page 1.
# 2025-01-01 13:55:00,520 - INFO - Starting API call for year 2012, division 2 and page 1
# 2025-01-01 13:55:00,616 - INFO - Successfully fetched data for year 2012, division 2 and page 1
# 2025-01-01 13:55:00,690 - INFO - Transforming rank and other columns.
# 2025-01-01 13:55:00,703 - INFO - Dataframe transformation complete. Returning dataframe.
# 2025-01-01 13:55:00,707 - INFO - Fetching games info score for year 2013
# 2025-01-01 13:55:00,708 - INFO - Processing division 1 for year 2013.
# 2025-01-01 13:55:00,709 - INFO - Fetching games info for year 2013 and division 1
# 2025-01-01 13:55:00,709 - INFO - Starting API call for year 2013, division 1 and page 1
# 2025-01-01 13:55:00,803 - INFO - Successfully fetched data for year 2013, division 1 and page 1
# 2025-01-01 13:55:00,806 - INFO - Fetched games metadata: competition_id 16, total_pages 1, total_competitors 47 and total_events 12
# 2025-01-01 13:55:00,807 - INFO - Total pages: 1, Total results: 47.
# 2025-01-01 13:55:00,807 - INFO - Fetching data for page 1.
# 2025-01-01 13:55:00,808 - INFO - Starting API call for year 2013, division 1 and page 1
# 2025-01-01 13:55:00,904 - INFO - Successfully fetched data for year 2013, division 1 and page 1
# 2025-01-01 13:55:00,981 - INFO - Processing division 2 for year 2013.
# 2025-01-01 13:55:00,981 - INFO - Fetching games info for year 2013 and division 2
# 2025-01-01 13:55:00,982 - INFO - Starting API call for year 2013, division 2 and page 1
# 2025-01-01 13:55:01,077 - INFO - Successfully fetched data for year 2013, division 2 and page 1
# 2025-01-01 13:55:01,079 - INFO - Fetched games metadata: competition_id 16, total_pages 1, total_competitors 44 and total_events 12
# 2025-01-01 13:55:01,080 - INFO - Total pages: 1, Total results: 44.
# 2025-01-01 13:55:01,081 - INFO - Fetching data for page 1.
# 2025-01-01 13:55:01,082 - INFO - Starting API call for year 2013, division 2 and page 1
# 2025-01-01 13:55:01,176 - INFO - Successfully fetched data for year 2013, division 2 and page 1
# 2025-01-01 13:55:01,260 - INFO - Transforming rank and other columns.
# 2025-01-01 13:55:01,273 - INFO - Dataframe transformation complete. Returning dataframe.
# 2025-01-01 13:55:01,277 - INFO - Fetching games info score for year 2014
# 2025-01-01 13:55:01,278 - INFO - Processing division 1 for year 2014.
# 2025-01-01 13:55:01,278 - INFO - Fetching games info for year 2014 and division 1
# 2025-01-01 13:55:01,279 - INFO - Starting API call for year 2014, division 1 and page 1
# 2025-01-01 13:55:01,374 - INFO - Successfully fetched data for year 2014, division 1 and page 1
# 2025-01-01 13:55:01,378 - INFO - Fetched games metadata: competition_id 15, total_pages 1, total_competitors 43 and total_events 13
# 2025-01-01 13:55:01,379 - INFO - Total pages: 1, Total results: 43.
# 2025-01-01 13:55:01,379 - INFO - Fetching data for page 1.
# 2025-01-01 13:55:01,381 - INFO - Starting API call for year 2014, division 1 and page 1
# 2025-01-01 13:55:01,493 - INFO - Successfully fetched data for year 2014, division 1 and page 1
# 2025-01-01 13:55:01,577 - INFO - Processing division 2 for year 2014.
# 2025-01-01 13:55:01,578 - INFO - Fetching games info for year 2014 and division 2
# 2025-01-01 13:55:01,579 - INFO - Starting API call for year 2014, division 2 and page 1
# 2025-01-01 13:55:01,676 - INFO - Successfully fetched data for year 2014, division 2 and page 1
# 2025-01-01 13:55:01,682 - INFO - Fetched games metadata: competition_id 15, total_pages 1, total_competitors 43 and total_events 13
# 2025-01-01 13:55:01,683 - INFO - Total pages: 1, Total results: 43.
# 2025-01-01 13:55:01,685 - INFO - Fetching data for page 1.
# 2025-01-01 13:55:01,686 - INFO - Starting API call for year 2014, division 2 and page 1
# 2025-01-01 13:55:01,781 - INFO - Successfully fetched data for year 2014, division 2 and page 1
# 2025-01-01 13:55:01,858 - INFO - Transforming rank and other columns.
# 2025-01-01 13:55:01,870 - INFO - Dataframe transformation complete. Returning dataframe.
# 2025-01-01 13:55:01,873 - INFO - Fetching games info score for year 2015
# 2025-01-01 13:55:01,874 - INFO - Processing division 1 for year 2015.
# 2025-01-01 13:55:01,875 - INFO - Fetching games info for year 2015 and division 1
# 2025-01-01 13:55:01,875 - INFO - Starting API call for year 2015, division 1 and page 1
# 2025-01-01 13:55:01,970 - INFO - Successfully fetched data for year 2015, division 1 and page 1
# 2025-01-01 13:55:01,972 - INFO - Fetched games metadata: competition_id 14, total_pages 1, total_competitors 40 and total_events 13
# 2025-01-01 13:55:01,973 - INFO - Total pages: 1, Total results: 40.
# 2025-01-01 13:55:01,973 - INFO - Fetching data for page 1.
# 2025-01-01 13:55:01,974 - INFO - Starting API call for year 2015, division 1 and page 1
# 2025-01-01 13:55:02,069 - INFO - Successfully fetched data for year 2015, division 1 and page 1
# 2025-01-01 13:55:02,129 - INFO - Processing division 2 for year 2015.
# 2025-01-01 13:55:02,130 - INFO - Fetching games info for year 2015 and division 2
# 2025-01-01 13:55:02,131 - INFO - Starting API call for year 2015, division 2 and page 1
# 2025-01-01 13:55:02,227 - INFO - Successfully fetched data for year 2015, division 2 and page 1
# 2025-01-01 13:55:02,229 - INFO - Fetched games metadata: competition_id 14, total_pages 1, total_competitors 40 and total_events 13
# 2025-01-01 13:55:02,231 - INFO - Total pages: 1, Total results: 40.
# 2025-01-01 13:55:02,231 - INFO - Fetching data for page 1.
# 2025-01-01 13:55:02,232 - INFO - Starting API call for year 2015, division 2 and page 1
# 2025-01-01 13:55:02,326 - INFO - Successfully fetched data for year 2015, division 2 and page 1
# 2025-01-01 13:55:02,390 - INFO - Transforming rank and other columns.
# 2025-01-01 13:55:02,401 - INFO - Dataframe transformation complete. Returning dataframe.
# 2025-01-01 13:55:02,404 - INFO - Fetching games info score for year 2016
# 2025-01-01 13:55:02,405 - INFO - Processing division 1 for year 2016.
# 2025-01-01 13:55:02,405 - INFO - Fetching games info for year 2016 and division 1
# 2025-01-01 13:55:02,406 - INFO - Starting API call for year 2016, division 1 and page 1
# 2025-01-01 13:55:02,500 - INFO - Successfully fetched data for year 2016, division 1 and page 1
# 2025-01-01 13:55:02,503 - INFO - Fetched games metadata: competition_id 13, total_pages 1, total_competitors 40 and total_events 15
# 2025-01-01 13:55:02,504 - INFO - Total pages: 1, Total results: 40.
# 2025-01-01 13:55:02,505 - INFO - Fetching data for page 1.
# 2025-01-01 13:55:02,505 - INFO - Starting API call for year 2016, division 1 and page 1
# 2025-01-01 13:55:02,608 - INFO - Successfully fetched data for year 2016, division 1 and page 1
# 2025-01-01 13:55:02,671 - INFO - Processing division 2 for year 2016.
# 2025-01-01 13:55:02,672 - INFO - Fetching games info for year 2016 and division 2
# 2025-01-01 13:55:02,672 - INFO - Starting API call for year 2016, division 2 and page 1
# 2025-01-01 13:55:02,767 - INFO - Successfully fetched data for year 2016, division 2 and page 1
# 2025-01-01 13:55:02,769 - INFO - Fetched games metadata: competition_id 13, total_pages 1, total_competitors 40 and total_events 15
# 2025-01-01 13:55:02,770 - INFO - Total pages: 1, Total results: 40.
# 2025-01-01 13:55:02,771 - INFO - Fetching data for page 1.
# 2025-01-01 13:55:02,772 - INFO - Starting API call for year 2016, division 2 and page 1
# 2025-01-01 13:55:02,865 - INFO - Successfully fetched data for year 2016, division 2 and page 1
# 2025-01-01 13:55:02,927 - INFO - Transforming rank and other columns.
# 2025-01-01 13:55:02,937 - INFO - Dataframe transformation complete. Returning dataframe.
# 2025-01-01 13:55:02,941 - INFO - Fetching games info score for year 2017
# 2025-01-01 13:55:02,942 - INFO - Processing division 1 for year 2017.
# 2025-01-01 13:55:02,942 - INFO - Fetching games info for year 2017 and division 1
# 2025-01-01 13:55:02,943 - INFO - Starting API call for year 2017, division 1 and page 1
# 2025-01-01 13:55:03,039 - INFO - Successfully fetched data for year 2017, division 1 and page 1
# 2025-01-01 13:55:03,042 - INFO - Fetched games metadata: competition_id 3, total_pages 1, total_competitors 39 and total_events 13
# 2025-01-01 13:55:03,044 - INFO - Total pages: 1, Total results: 39.
# 2025-01-01 13:55:03,044 - INFO - Fetching data for page 1.
# 2025-01-01 13:55:03,045 - INFO - Starting API call for year 2017, division 1 and page 1
# 2025-01-01 13:55:03,142 - INFO - Successfully fetched data for year 2017, division 1 and page 1
# 2025-01-01 13:55:03,201 - INFO - Processing division 2 for year 2017.
# 2025-01-01 13:55:03,201 - INFO - Fetching games info for year 2017 and division 2
# 2025-01-01 13:55:03,202 - INFO - Starting API call for year 2017, division 2 and page 1
# 2025-01-01 13:55:03,299 - INFO - Successfully fetched data for year 2017, division 2 and page 1
# 2025-01-01 13:55:03,301 - INFO - Fetched games metadata: competition_id 3, total_pages 1, total_competitors 40 and total_events 13
# 2025-01-01 13:55:03,302 - INFO - Total pages: 1, Total results: 40.
# 2025-01-01 13:55:03,303 - INFO - Fetching data for page 1.
# 2025-01-01 13:55:03,303 - INFO - Starting API call for year 2017, division 2 and page 1
# 2025-01-01 13:55:03,397 - INFO - Successfully fetched data for year 2017, division 2 and page 1
# 2025-01-01 13:55:03,460 - INFO - Transforming rank and other columns.
# 2025-01-01 13:55:03,469 - INFO - Dataframe transformation complete. Returning dataframe.
# 2025-01-01 13:55:03,474 - INFO - Fetching games info score for year 2018
# 2025-01-01 13:55:03,474 - INFO - Processing division 1 for year 2018.
# 2025-01-01 13:55:03,475 - INFO - Fetching games info for year 2018 and division 1
# 2025-01-01 13:55:03,476 - INFO - Starting API call for year 2018, division 1 and page 1
# 2025-01-01 13:55:03,570 - INFO - Successfully fetched data for year 2018, division 1 and page 1
# 2025-01-01 13:55:03,573 - INFO - Fetched games metadata: competition_id 31, total_pages 1, total_competitors 40 and total_events 14
# 2025-01-01 13:55:03,574 - INFO - Total pages: 1, Total results: 40.
# 2025-01-01 13:55:03,574 - INFO - Fetching data for page 1.
# 2025-01-01 13:55:03,575 - INFO - Starting API call for year 2018, division 1 and page 1
# 2025-01-01 13:55:03,668 - INFO - Successfully fetched data for year 2018, division 1 and page 1
# 2025-01-01 13:55:03,732 - INFO - Processing division 2 for year 2018.
# 2025-01-01 13:55:03,733 - INFO - Fetching games info for year 2018 and division 2
# 2025-01-01 13:55:03,734 - INFO - Starting API call for year 2018, division 2 and page 1
# 2025-01-01 13:55:03,830 - INFO - Successfully fetched data for year 2018, division 2 and page 1
# 2025-01-01 13:55:03,832 - INFO - Fetched games metadata: competition_id 31, total_pages 1, total_competitors 40 and total_events 14
# 2025-01-01 13:55:03,833 - INFO - Total pages: 1, Total results: 40.
# 2025-01-01 13:55:03,834 - INFO - Fetching data for page 1.
# 2025-01-01 13:55:03,835 - INFO - Starting API call for year 2018, division 2 and page 1
# 2025-01-01 13:55:03,933 - INFO - Successfully fetched data for year 2018, division 2 and page 1
# 2025-01-01 13:55:03,997 - INFO - Transforming rank and other columns.
# 2025-01-01 13:55:04,007 - INFO - Dataframe transformation complete. Returning dataframe.
# 2025-01-01 13:55:04,012 - INFO - Fetching games info score for year 2019
# 2025-01-01 13:55:04,013 - INFO - Processing division 1 for year 2019.
# 2025-01-01 13:55:04,014 - INFO - Fetching games info for year 2019 and division 1
# 2025-01-01 13:55:04,015 - INFO - Starting API call for year 2019, division 1 and page 1
# 2025-01-01 13:55:04,109 - INFO - Successfully fetched data for year 2019, division 1 and page 1
# 2025-01-01 13:55:04,112 - INFO - Fetched games metadata: competition_id 52, total_pages 3, total_competitors 144 and total_events 12
# 2025-01-01 13:55:04,113 - INFO - Total pages: 3, Total results: 144.
# 2025-01-01 13:55:04,114 - INFO - Fetching data for page 1.
# 2025-01-01 13:55:04,115 - INFO - Starting API call for year 2019, division 1 and page 1
# 2025-01-01 13:55:04,209 - INFO - Successfully fetched data for year 2019, division 1 and page 1
# 2025-01-01 13:55:04,286 - INFO - Fetching data for page 2.
# 2025-01-01 13:55:04,286 - INFO - Starting API call for year 2019, division 1 and page 2
# 2025-01-01 13:55:04,379 - INFO - Successfully fetched data for year 2019, division 1 and page 2
# 2025-01-01 13:55:04,455 - INFO - Fetching data for page 3.
# 2025-01-01 13:55:04,456 - INFO - Starting API call for year 2019, division 1 and page 3
# 2025-01-01 13:55:04,550 - INFO - Successfully fetched data for year 2019, division 1 and page 3
# 2025-01-01 13:55:04,620 - INFO - Processing division 2 for year 2019.
# 2025-01-01 13:55:04,620 - INFO - Fetching games info for year 2019 and division 2
# 2025-01-01 13:55:04,621 - INFO - Starting API call for year 2019, division 2 and page 1
# 2025-01-01 13:55:04,716 - INFO - Successfully fetched data for year 2019, division 2 and page 1
# 2025-01-01 13:55:04,718 - INFO - Fetched games metadata: competition_id 52, total_pages 3, total_competitors 131 and total_events 12
# 2025-01-01 13:55:04,719 - INFO - Total pages: 3, Total results: 131.
# 2025-01-01 13:55:04,719 - INFO - Fetching data for page 1.
# 2025-01-01 13:55:04,719 - INFO - Starting API call for year 2019, division 2 and page 1
# 2025-01-01 13:55:04,813 - INFO - Successfully fetched data for year 2019, division 2 and page 1
# 2025-01-01 13:55:04,896 - INFO - Fetching data for page 2.
# 2025-01-01 13:55:04,896 - INFO - Starting API call for year 2019, division 2 and page 2
# 2025-01-01 13:55:04,991 - INFO - Successfully fetched data for year 2019, division 2 and page 2
# 2025-01-01 13:55:05,076 - INFO - Fetching data for page 3.
# 2025-01-01 13:55:05,076 - INFO - Starting API call for year 2019, division 2 and page 3
# 2025-01-01 13:55:05,170 - INFO - Successfully fetched data for year 2019, division 2 and page 3
# 2025-01-01 13:55:05,225 - INFO - Transforming rank and other columns.
# 2025-01-01 13:55:05,243 - INFO - Dataframe transformation complete. Returning dataframe.
# 2025-01-01 13:55:05,249 - INFO - Fetching games info score for year 2020
# 2025-01-01 13:55:05,250 - INFO - Processing division 1 for year 2020.
# 2025-01-01 13:55:05,250 - INFO - Fetching games info for year 2020 and division 1
# 2025-01-01 13:55:05,251 - INFO - Starting API call for year 2020, division 1 and page 1
# 2025-01-01 13:55:05,345 - INFO - Successfully fetched data for year 2020, division 1 and page 1
# 2025-01-01 13:55:05,348 - INFO - Fetched games metadata: competition_id 58, total_pages 1, total_competitors 30 and total_events 20
# 2025-01-01 13:55:05,348 - INFO - Total pages: 1, Total results: 30.
# 2025-01-01 13:55:05,349 - INFO - Fetching data for page 1.
# 2025-01-01 13:55:05,349 - INFO - Starting API call for year 2020, division 1 and page 1
# 2025-01-01 13:55:05,442 - INFO - Successfully fetched data for year 2020, division 1 and page 1
# 2025-01-01 13:55:05,488 - INFO - Processing division 2 for year 2020.
# 2025-01-01 13:55:05,489 - INFO - Fetching games info for year 2020 and division 2
# 2025-01-01 13:55:05,489 - INFO - Starting API call for year 2020, division 2 and page 1
# 2025-01-01 13:55:05,586 - INFO - Successfully fetched data for year 2020, division 2 and page 1
# 2025-01-01 13:55:05,588 - INFO - Fetched games metadata: competition_id 58, total_pages 1, total_competitors 30 and total_events 20
# 2025-01-01 13:55:05,589 - INFO - Total pages: 1, Total results: 30.
# 2025-01-01 13:55:05,590 - INFO - Fetching data for page 1.
# 2025-01-01 13:55:05,591 - INFO - Starting API call for year 2020, division 2 and page 1
# 2025-01-01 13:55:05,684 - INFO - Successfully fetched data for year 2020, division 2 and page 1
# 2025-01-01 13:55:05,736 - INFO - Transforming rank and other columns.
# 2025-01-01 13:55:05,746 - INFO - Dataframe transformation complete. Returning dataframe.
# 2025-01-01 13:55:05,752 - INFO - Fetching games info score for year 2021
# 2025-01-01 13:55:05,752 - INFO - Processing division 1 for year 2021.
# 2025-01-01 13:55:05,753 - INFO - Fetching games info for year 2021 and division 1
# 2025-01-01 13:55:05,753 - INFO - Starting API call for year 2021, division 1 and page 1
# 2025-01-01 13:55:05,848 - INFO - Successfully fetched data for year 2021, division 1 and page 1
# 2025-01-01 13:55:05,851 - INFO - Fetched games metadata: competition_id 161, total_pages 1, total_competitors 40 and total_events 15
# 2025-01-01 13:55:05,852 - INFO - Total pages: 1, Total results: 40.
# 2025-01-01 13:55:05,852 - INFO - Fetching data for page 1.
# 2025-01-01 13:55:05,853 - INFO - Starting API call for year 2021, division 1 and page 1
# 2025-01-01 13:55:05,947 - INFO - Successfully fetched data for year 2021, division 1 and page 1
# 2025-01-01 13:55:06,008 - INFO - Processing division 2 for year 2021.
# 2025-01-01 13:55:06,009 - INFO - Fetching games info for year 2021 and division 2
# 2025-01-01 13:55:06,011 - INFO - Starting API call for year 2021, division 2 and page 1
# 2025-01-01 13:55:06,106 - INFO - Successfully fetched data for year 2021, division 2 and page 1
# 2025-01-01 13:55:06,109 - INFO - Fetched games metadata: competition_id 161, total_pages 1, total_competitors 40 and total_events 15
# 2025-01-01 13:55:06,109 - INFO - Total pages: 1, Total results: 40.
# 2025-01-01 13:55:06,110 - INFO - Fetching data for page 1.
# 2025-01-01 13:55:06,110 - INFO - Starting API call for year 2021, division 2 and page 1
# 2025-01-01 13:55:06,212 - INFO - Successfully fetched data for year 2021, division 2 and page 1
# 2025-01-01 13:55:06,278 - INFO - Transforming rank and other columns.
# 2025-01-01 13:55:06,289 - INFO - Dataframe transformation complete. Returning dataframe.
# 2025-01-01 13:55:06,296 - INFO - Fetching games info score for year 2022
# 2025-01-01 13:55:06,297 - INFO - Processing division 1 for year 2022.
# 2025-01-01 13:55:06,297 - INFO - Fetching games info for year 2022 and division 1
# 2025-01-01 13:55:06,298 - INFO - Starting API call for year 2022, division 1 and page 1
# 2025-01-01 13:55:06,393 - INFO - Successfully fetched data for year 2022, division 1 and page 1
# 2025-01-01 13:55:06,395 - INFO - Fetched games metadata: competition_id 189, total_pages 1, total_competitors 40 and total_events 14
# 2025-01-01 13:55:06,396 - INFO - Total pages: 1, Total results: 40.
# 2025-01-01 13:55:06,397 - INFO - Fetching data for page 1.
# 2025-01-01 13:55:06,398 - INFO - Starting API call for year 2022, division 1 and page 1
# 2025-01-01 13:55:06,488 - INFO - Successfully fetched data for year 2022, division 1 and page 1
# 2025-01-01 13:55:06,549 - INFO - Processing division 2 for year 2022.
# 2025-01-01 13:55:06,549 - INFO - Fetching games info for year 2022 and division 2
# 2025-01-01 13:55:06,550 - INFO - Starting API call for year 2022, division 2 and page 1
# 2025-01-01 13:55:06,645 - INFO - Successfully fetched data for year 2022, division 2 and page 1
# 2025-01-01 13:55:06,648 - INFO - Fetched games metadata: competition_id 189, total_pages 1, total_competitors 40 and total_events 14
# 2025-01-01 13:55:06,648 - INFO - Total pages: 1, Total results: 40.
# 2025-01-01 13:55:06,649 - INFO - Fetching data for page 1.
# 2025-01-01 13:55:06,649 - INFO - Starting API call for year 2022, division 2 and page 1
# 2025-01-01 13:55:06,743 - INFO - Successfully fetched data for year 2022, division 2 and page 1
# 2025-01-01 13:55:06,806 - INFO - Transforming rank and other columns.
# 2025-01-01 13:55:06,818 - INFO - Dataframe transformation complete. Returning dataframe.
# 2025-01-01 13:55:06,822 - INFO - Fetching games info score for year 2023
# 2025-01-01 13:55:06,823 - INFO - Processing division 1 for year 2023.
# 2025-01-01 13:55:06,824 - INFO - Fetching games info for year 2023 and division 1
# 2025-01-01 13:55:06,824 - INFO - Starting API call for year 2023, division 1 and page 1
# 2025-01-01 13:55:06,917 - INFO - Successfully fetched data for year 2023, division 1 and page 1
# 2025-01-01 13:55:06,920 - INFO - Fetched games metadata: competition_id 223, total_pages 1, total_competitors 40 and total_events 12
# 2025-01-01 13:55:06,920 - INFO - Total pages: 1, Total results: 40.
# 2025-01-01 13:55:06,921 - INFO - Fetching data for page 1.
# 2025-01-01 13:55:06,921 - INFO - Starting API call for year 2023, division 1 and page 1
# 2025-01-01 13:55:07,015 - INFO - Successfully fetched data for year 2023, division 1 and page 1
# 2025-01-01 13:55:07,074 - INFO - Processing division 2 for year 2023.
# 2025-01-01 13:55:07,075 - INFO - Fetching games info for year 2023 and division 2
# 2025-01-01 13:55:07,075 - INFO - Starting API call for year 2023, division 2 and page 1
# 2025-01-01 13:55:07,192 - INFO - Successfully fetched data for year 2023, division 2 and page 1
# 2025-01-01 13:55:07,195 - INFO - Fetched games metadata: competition_id 223, total_pages 1, total_competitors 40 and total_events 12
# 2025-01-01 13:55:07,196 - INFO - Total pages: 1, Total results: 40.
# 2025-01-01 13:55:07,196 - INFO - Fetching data for page 1.
# 2025-01-01 13:55:07,197 - INFO - Starting API call for year 2023, division 2 and page 1
# 2025-01-01 13:55:07,292 - INFO - Successfully fetched data for year 2023, division 2 and page 1
# 2025-01-01 13:55:07,363 - INFO - Transforming rank and other columns.
# 2025-01-01 13:55:07,376 - INFO - Dataframe transformation complete. Returning dataframe.
# 2025-01-01 13:55:07,384 - INFO - Fetching games info score for year 2024
# 2025-01-01 13:55:07,385 - INFO - Processing division 1 for year 2024.
# 2025-01-01 13:55:07,385 - INFO - Fetching games info for year 2024 and division 1
# 2025-01-01 13:55:07,386 - INFO - Starting API call for year 2024, division 1 and page 1
# 2025-01-01 13:55:07,486 - INFO - Successfully fetched data for year 2024, division 1 and page 1
# 2025-01-01 13:55:07,488 - INFO - Fetched games metadata: competition_id 225, total_pages 1, total_competitors 39 and total_events 10
# 2025-01-01 13:55:07,489 - INFO - Total pages: 1, Total results: 39.
# 2025-01-01 13:55:07,490 - INFO - Fetching data for page 1.
# 2025-01-01 13:55:07,490 - INFO - Starting API call for year 2024, division 1 and page 1
# 2025-01-01 13:55:07,582 - INFO - Successfully fetched data for year 2024, division 1 and page 1
# 2025-01-01 13:55:07,653 - INFO - Processing division 2 for year 2024.
# 2025-01-01 13:55:07,654 - INFO - Fetching games info for year 2024 and division 2
# 2025-01-01 13:55:07,655 - INFO - Starting API call for year 2024, division 2 and page 1
# 2025-01-01 13:55:07,751 - INFO - Successfully fetched data for year 2024, division 2 and page 1
# 2025-01-01 13:55:07,753 - INFO - Fetched games metadata: competition_id 225, total_pages 1, total_competitors 40 and total_events 10
# 2025-01-01 13:55:07,754 - INFO - Total pages: 1, Total results: 40.
# 2025-01-01 13:55:07,754 - INFO - Fetching data for page 1.
# 2025-01-01 13:55:07,755 - INFO - Starting API call for year 2024, division 2 and page 1
# 2025-01-01 13:55:07,851 - INFO - Successfully fetched data for year 2024, division 2 and page 1
# 2025-01-01 13:55:07,915 - INFO - Transforming rank and other columns.
# 2025-01-01 13:55:07,924 - INFO - Dataframe transformation complete. Returning dataframe.
# /Users/lindalarusdottir/Arnar/Projects/CrossfitGames/src/crossfitgames/api/api_calls.py:281: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_games_info_scores_multiple = pd.concat([df_games_info_scores_multiple, df_temp], ignore_index=True)

# %%
games_info = pd.read_csv(f'../data/{file_name}.csv')
games_info.head(5)
# Out:
#    Unnamed: 0  ordinal  rank  score  valid scoreDisplay       scoreIdentifier  \
# 0           0        1   2.0     95    1.0        13:39  75881c2cd249b98185a8
# 1           1        2   2.0     95    1.0        20:45  bf9d6716056044146079
# 2           2        3  11.0     82    1.0     906.4 lb  a355dcd3303b9b861ba0
# 3           3        1   1.0    100    1.0        13:07  ed155ea36b3781f16914
# 4           4        2   3.0     90    1.0        22:00  b25717e51efa6f0d783d
#
#    mobileScoreDisplay  scaled  video  heat  lane breakdown  competitorId  \
# 0                 NaN       0      0   NaN   NaN    95 pts        164070
# 1                 NaN       0      0   NaN   NaN    95 pts        164070
# 2                 NaN       0      0   NaN   NaN    82 pts        164070
# 3                 NaN       0      0   NaN   NaN   100 pts         57785
# 4                 NaN       0      0   NaN   NaN    90 pts         57785
#
#    year  division rankReason  scoreIsWeightInKg
# 0  2007         1        NaN                NaN
# 1  2007         1        NaN                NaN
# 2  2007         1        NaN              411.0
# 3  2007         1        NaN                NaN
# 4  2007         1        NaN                NaN

# %%
games_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20282 entries, 0 to 20281
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          20282 non-null  int64
#  1   ordinal             20282 non-null  int64
#  2   rank                19481 non-null  float64
#  3   score               20282 non-null  int64
#  4   valid               14594 non-null  float64
#  5   scoreDisplay        14880 non-null  object
#  6   scoreIdentifier     20195 non-null  object
#  7   mobileScoreDisplay  0 non-null      float64
#  8   scaled              20282 non-null  int64
#  9   video               20282 non-null  int64
#  10  heat                0 non-null      float64
#  11  lane                0 non-null      float64
#  12  breakdown           13795 non-null  object
#  13  competitorId        20282 non-null  int64
#  14  year                20282 non-null  int64
#  15  division            20282 non-null  int64
#  16  rankReason          4046 non-null   object
#  17  scoreIsWeightInKg   1149 non-null   float64
# dtypes: float64(6), int64(8), object(4)
# memory usage: 2.8+ MB

# %%
games_info[games_info['year'] == 2017]
# Out:
#        Unnamed: 0  ordinal  rank  score  valid scoreDisplay  \
# 9565         9565        1   7.0     72    1.0     29:40.50
# 9566         9566        2   2.0     94    1.0     19:52.68
# 9567         9567        3   2.0     94    1.0      8:17.88
# 9568         9568        4   6.0     76    1.0         6 pt
# 9569         9569        5   5.0     80    1.0       291 lb
# ...           ...      ...   ...    ...    ...          ...
# 10587       10587        9   0.0      0    NaN          NaN
# 10588       10588       10   0.0      0    NaN          NaN
# 10589       10589       11   0.0      0    NaN          NaN
# 10590       10590       12   0.0      0    NaN          NaN
# 10591       10591       13   0.0      0    NaN          NaN
#
#             scoreIdentifier  mobileScoreDisplay  scaled  video  heat  lane  \
# 9565   20ccb935305398596530                 NaN       0      0   NaN   NaN
# 9566   351c94754292983375b8                 NaN       0      0   NaN   NaN
# 9567   904789e17f990f4cafae                 NaN       0      0   NaN   NaN
# 9568   496921b34f7ce0ee38cb                 NaN       0      0   NaN   NaN
# 9569   a3335bfc298a35a0840e                 NaN       0      0   NaN   NaN
# ...                     ...                 ...     ...    ...   ...   ...
# 10587  adf6d7a058c2ebf01d8c                 NaN       0      0   NaN   NaN
# 10588  405e8a659b6d31a7a03d                 NaN       0      0   NaN   NaN
# 10589  690b67ae81e1a3524d3f                 NaN       0      0   NaN   NaN
# 10590  a4ac5c37da8fa9b4edd2                 NaN       0      0   NaN   NaN
# 10591  6dcefaa244de2321045f                 NaN       0      0   NaN   NaN
#
#       breakdown  competitorId  year  division rankReason  scoreIsWeightInKg
# 9565     72 pts        153604  2017         1        NaN                NaN
# 9566     94 pts        153604  2017         1        NaN                NaN
# 9567     94 pts        153604  2017         1        NaN                NaN
# 9568     76 pts        153604  2017         1        NaN                NaN
# 9569     80 pts        153604  2017         1        NaN              132.0
# ...         ...           ...   ...       ...        ...                ...
# 10587       NaN        189706  2017         2         WD                NaN
# 10588       NaN        189706  2017         2         WD                NaN
# 10589       NaN        189706  2017         2         WD                NaN
# 10590       NaN        189706  2017         2         WD                NaN
# 10591       NaN        189706  2017         2         WD                NaN
#
# [1027 rows x 18 columns]
